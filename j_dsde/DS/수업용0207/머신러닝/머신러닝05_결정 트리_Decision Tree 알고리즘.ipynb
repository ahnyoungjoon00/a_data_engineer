# %% [markdown]
# ## 결정 트리(Decision Tree)  알고리즘

# %% [markdown]
# ### 결정 트리 알고리즘
# - 학습을 통해 데이터에 있는 규칙을 자동으로 찾아내 트리 기반의 분류 규칙을 만드는 알고리즘
# - ML 알고리즘 중 직관적으로 이해하기 쉬운 알고리즘으로 분류와 회귀 문제에서 가장 널리 사용
# - 특정 기준(질문)에 따라서 데이터를 구분
# - 가장 쉬운 규칙 표현 방법 : if ~ else 기반
#
#
# ### 결정트리 유형
# - 분류 트리
#     - 범주형 목표 변수를 기준으로 마디를 나눔
#     - 끝마디(말단 노드)에 포함된 자료의 범주가 분류 결과 값이 됨
#
# - 회귀 트리
#     - 연속형 목표 변수를 기준으로 마디를 나눔
#     - 끝마디(말단 노드)에 포함된 자료의 평균값이 각 끝마디의 회귀 값이 됨

# %% [markdown]
# ### Tree 구조
# - 전체적인 모양이 나무를 뒤집어 놓은 것과 닮았다고 해서 붙여진 이름
# - 결정 트리에서 질문이나 네모 상자를 노드(Node)라고 함
# - 맨 위의 노드(첫 질문)를 Root Node
# - 각 질문에 대한 마지막 노드를 Leaf Node : 결정된 클래스 값
#     - 말단 노드 : 더 이상 분할하지 않는 노드
#         - 규칙 없음
# - 규칙 노드 (Decision Node) : 규칙 조건을 갖고 있는 노드 (이 규칙에 따라 분할)
# - 새로운 규칙 조건만 Sub Tree  생성
#
# #### 용어
# - Root Node :
#     - 모든 데이터를 포함하는 의사결정 트리의 줄발점
#     - 데이터를 몇 개의 동일한 그룹으로 분할
# - Leaf Node
#     - 최종 결과를 나타내는 노드(마디)
#     - 말단 노드 (자식 노드 없음)
#     - 데이터를 더 이상 분할하지 않음
#     - 분할하기 위한 규칙 없음
# - Parent/Child Node
#     - 상위 노드 / 하위 노드
# - Spliting
#     - 주어진 조건에 따라 데이터를 분할하는 작업
# - Branch/Sub Tree
#     - 트리를 분리하여 생성된 하위 트리
# - Depth
#     - Root부터 마지막 노드까지 경로의 길이
#     - 아래 그림에서는 depth=3이 됨

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 결정트리에서 중요한 이슈
# - 데이터 세트의 피처가 결합해 규칙 조건을 만들 때마다 규칙노드가 만들어짐
# - 규칙이 많아지면 결정 방식이 복잡해지고 과적합(overfitting) 발생
#     - 즉, depth가 길어질수록 결정트리의 예측 성능이 저하될 가능성이 높음
# - 가능한 적은 결정노드로 높은 예측 정확도를 가지려면
#     - 데이터를 분류할 때 최대한 많은 데이터 세트가 해당 분류에 속할 수 있도록
#     - 결정 노드의 규칙이 정해져야 함
# - 그러기 위해서 어떻게 트리를 분할할 것인가가 중요
#     - 최대한 균일한 데이터 세트를 구성할 수 있도록 분할하는 것이 필요

# %% [markdown]
# ### 가지치기 (pruning)
# - 특정 노드 밑의 하부 트리를 제거하여 일반화 성능을 높이는 방법
# - 깊이가 줄어들고 결과의 개수 줄어듦
# - 과적합 발생을 막기 위한 방법
# - (트리에 가지가 너무 많으면 과적합(overfitting) 발생)

# %% [markdown]
# ### 결정 트리 장단점
# - 장점
#     - 매우 쉽고 유연하게 적용될 수 있는 알고리즘
#     - 정보 균일도 룰을 기반으로 알고리즘이 쉽고 직관적이며 명확함
#     - 데이터 스케일링(표준화/정규화) 등의 사전 가공의 영향이 적음
#
# - 단점
#     - 규칙이 많아지면 결정 방식 복잡해지고 과적합 발생
#     - 즉, depth가 길어질수록 결정트리의 예측 성능이 저하될 가능성이 높음
#     - 전반적으로 결정트리 알고리즘 성능이 낮음 --> 앙상블

# %% [markdown]
# ### 균일도 (불순도 : impurity)

# %% [markdown]
# #### 균일도
# - 같은 것(값)끼리 섞여 있는 정도
# - 한가지 종류만 있는 경우 균일도 높고
# - 여러 가지가 섞여 있는 경우 균일도 낮고, 혼잡도 높음
# - 규칙 조건 생성에서 중요한 것
# - 정보 균일도가 높은 데이터 세트를 먼저 선택할 수 있도록 규칙 조건을 만든 것이 중요

# %% [markdown]
# #### 균일한 데이터 세트
# - 데이터 세트의 균일도는 데이터를 구분하는 데 필요한 정보의 양에 영향을 미침
#
# - A : 하얀공, 검은공 비슷하게 섞여 있음. 혼잡도가 높고 균일도가 낮음
# - B : 일부 하얀공, 대부분 검은공
# - C : 모두 검은공. 균일도 가장 높음
#
# C에서 데이터를 추출했을 때 데이터에 대한 별다른 정보 없이도 '검은공'이라고 쉽게 예측 가능
# A의 경우는 상대적으로 혼잡도가 높교 균일도가 낮기 때문에
# 같은 조건에서 데이터를 판단하는 데 더 많은 정보 필요

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 엔트로피 (Entropy)
# - 데이터 분포의 불순도(impurity)를 수치화한 지표
# - 서로 다른 데이터가 섞여 있으면 엔트로피가 높고
# - 같은 값이 섞여 있으면 엔트로피 낮음
# - 엔트로피를 통해 불순도 판단
# - 수치 0 : 모든 값이 동일 (분류하지 않아도 됨)
# - 수치 1 : 불순도 최대
#
# #### 정보 이득(Information Gain) 지수
# - 분류를 통해 정보에 대해 얻은 지식
# - 1-엔트로피 지수
# - 결정트리는 정보 이득 지수로 분할 기준을 정함
# - 즉, 정보 이득 지수가 높은 속성을 기준으로 분할
#
# #### 지니 계수
# - 불순도를 수치화한 지표
#     - 경제학에서 불평등 지수를 나타낼 때 사용하는 계수
#     - 0이 가장 평등하고, 1로 갈수록 불평등
# - 머신러닝에 적용될 때는 지니 계수가 낮을수록
#     - 데이터 균일도가 높은 것으로 해석
#     - gini = 0.0 (불순도 0: 한 종류라는 의미)
#
# #### 결정 트리 알고리즘에서 지니 계수 이용
# - 사이킷런의 DecisionTreeClassifier 클래스는
# - 기본으로 지니 계수를 이용해서 데이터 세트 분할
# - 데이터 세트를 분할하는 데 가장 좋은 조건
#     - 정보 이득이 높거나 지니 계수가 낮은 조건
#     - 지니 계수가 낮은 속성을 기준으로 분할
#
# #### 결정 트리 알고리즘에서 분류를 결정하는 과정
# - 정보 이득이 높거나 지니 계수가 낮은 조건을 찾아서
# - 자식 트리 노드에 걸쳐 반복적으로 분할한 뒤
# - 데이터가 모두 특정 분류에 속하게 되면
#     - 분할을 멈추고 분류 결정
#     - 이때의 지니 계수는 0

# %% [markdown]
# #### 분류 결정 과정
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 사이킷런의 결정트리 알고리즘 클래스
# - 분류 모델을 위한 DecisionTreeClassifier
# - 회귀 모델을 위한 DecisionTreeRegressor
# - 결정 트리를 위한 클래스의 매개변수
#     - 분류, 회귀 모두 동일하게 적용
# ---
# ### CART(Classification And Regression Trees) 기반 알고리즘
# - 분류뿐만 아니라 회귀도 가능
# - 결정트리, 랜덤 포레트스, GBM, XGBoost, LightGBM 등 트리 기반 알고리즘
# - 트리의 노드마다 이진 분류(Binary classification)하는 특징
# - 일반적으로 지니 계수(데이터 군집의 불순도를 측정하는 지표)를 사용
# - 지니 계수가 낮을 수록 균일도가 높다 (같은 것끼리 모여있음)
# - 따라서 CART 알고리즘은 지니 계수가 높은 방향으로 트리 생성해서 Decision Tree의 노드 구성

# %% [markdown]
# ### 의사 결정 트리 예제

# %% [markdown]
# #### 붓꽃 데이터 세트에 결정 트리 적용
# - DecisionTreeClassifier 이용해 학습한 뒤
# - 규칙 트리 시각화

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"

import warnings
warnings.filterwarnings(action='ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 데이터 셋트 로드 및 분리

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# 데이터 세트 로드
iris_data = load_iris()

# 학습/테스트 데이터 세트로 분리
X_train, X_test, y_train, y_test = train_test_split(iris_data.data, 
                                                    iris_data.target, 
                                                    test_size=0.2, 
                                                    random_state=11)

# %%
# 의사결정 트리 Classifier (분류기) 생성 및 학습
from sklearn.tree import DecisionTreeClassifier

# 모델 생성 및 학습
dt_clf = DecisionTreeClassifier(random_state=156)
dt_clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=156)

# %%
help(plot_tree)
# Out:
# Help on function plot_tree in module sklearn.tree._export:
#
# plot_tree(decision_tree, *, max_depth=None, feature_names=None, class_names=None, label='all', filled=False, impurity=True, node_ids=False, proportion=False, rounded=False, precision=3, ax=None, fontsize=None)
#     Plot a decision tree.
#
#     The sample counts that are shown are weighted with any sample_weights that
#     might be present.
#
#     The visualization is fit automatically to the size of the axis.
#     Use the ``figsize`` or ``dpi`` arguments of ``plt.figure``  to control
#     the size of the rendering.
#
#     Read more in the :ref:`User Guide <tree>`.
#
#     .. versionadded:: 0.21
#
#     Parameters
#     ----------
#     decision_tree : decision tree regressor or classifier
#         The decision tree to be plotted.
#
#     max_depth : int, default=None
#         The maximum depth of the representation. If None, the tree is fully
#         generated.
#
# ...

# %%
# plot_tree() 사용하여 트리 그래프 출력 
from sklearn.tree import plot_tree

plt.figure(figsize=(10,7))
plot_tree(dt_clf, filled=True, feature_names=iris_data.feature_names)
plt.show()
# Out:
# [Text(0.3076923076923077, 0.9166666666666666, 'petal length (cm) <= 2.45\ngini = 0.667\nsamples = 120\nvalue = [41, 40, 39]'),
#  Text(0.23076923076923078, 0.75, 'gini = 0.0\nsamples = 41\nvalue = [41, 0, 0]'),
#  Text(0.2692307692307693, 0.8333333333333333, 'True  '),
#  Text(0.38461538461538464, 0.75, 'petal width (cm) <= 1.55\ngini = 0.5\nsamples = 79\nvalue = [0, 40, 39]'),
#  Text(0.34615384615384615, 0.8333333333333333, '  False'),
#  Text(0.15384615384615385, 0.5833333333333334, 'petal length (cm) <= 5.25\ngini = 0.051\nsamples = 38\nvalue = [0, 37, 1]'),
#  Text(0.07692307692307693, 0.4166666666666667, 'gini = 0.0\nsamples = 37\nvalue = [0, 37, 0]'),
#  Text(0.23076923076923078, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.6153846153846154, 0.5833333333333334, 'petal width (cm) <= 1.75\ngini = 0.136\nsamples = 41\nvalue = [0, 3, 38]'),
# ...

# %%
# 트리에서 리프노드중에 1개 2개때문에 떨어져나온 노드들은 과적합일 가능성이 꽤나 높음
# 여기에서는 정확도가 높아지는건 맞겟지만 실제 적용하면 오히려 오차가 커질 가능성
# 과적합이 시작된 노드인 2번째 노드정도에서 depth 쪼개는 것을 중지시키도록하는게 옳음

# %%
# 피처 이름과 타겟 이름 확인
iris_data.feature_names
iris_data.target_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
# max_depth=1 설정하고 트리 그래프 출력 

plt.figure(figsize=(10,7))
plot_tree(dt_clf, max_depth=1, filled=True, feature_names=iris_data.feature_names)
plt.show()
# Out:
# [Text(0.4, 0.8333333333333334, 'petal length (cm) <= 2.45\ngini = 0.667\nsamples = 120\nvalue = [41, 40, 39]'),
#  Text(0.2, 0.5, 'gini = 0.0\nsamples = 41\nvalue = [41, 0, 0]'),
#  Text(0.30000000000000004, 0.6666666666666667, 'True  '),
#  Text(0.6, 0.5, 'petal width (cm) <= 1.55\ngini = 0.5\nsamples = 79\nvalue = [0, 40, 39]'),
#  Text(0.5, 0.6666666666666667, '  False'),
#  Text(0.4, 0.16666666666666666, '\n  (...)  \n'),
#  Text(0.8, 0.16666666666666666, '\n  (...)  \n')]

# %% [markdown]
# ### 트리 그래프 설명
# - max_depth=1인 경우

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Root Node 내 지표 설명
# - 분할 규칙 : petal length (cm) <= 2.45
#     - 2.45 이하이면 왼쪽, 크면 오른쪽으로 분할
# - samples = 120 개 (y_train.size로 확인)
# - 각 클래스 별 데이터 건수 : [41, 40, 39] (3종류가 섞여 있음)
#     - setosa : 41, versicola : 40, virginica : 39 개
#     - 조건에 따라 분할하게 되면
#       - 최종 클래스(레이블) 값[41] : class = setosa
#         - 분할하여 왼쪽 리프 노트가 setosa 41 개로 결정 -> [41, 0, 0]
#         - 40, 39를 다른 규칙으로 분할 진행

# %%
# samples = 120 총 샘플 수
y_train.size
y_train.shape
# Out:
# 120
# (120,)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 왼쪽 첫 번째 리프 노드
# - 분할 조건 없음 (말단 노드 : 더 이상 분할하지 않음)
# - gini = 0.0 (불순도 0: 한 종류라는 의미)
#     - gini 계수가 0으로 한 종류로 최종 분할되었기 때문에 더 이상 분할하지 않음
#     - (결정트리는 불순도를 최소화하는 것이 목표)
# - vlaue = [41, 0, 0]
#     - 0 : setosa만 41 개
#     - 최종 결정값

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Root Node에서 분할된 오른쪽 노드 (하위 노드/자식 노드)
# - 리프 노드 아님 (말단 노드 아님)
# - 현재 2개의 품종이 40, 39 섞여 있는 상태
# - 즉, 다시 조건에 의해 분할되어야 하는 노드 : 분할 조건 ( <= 1.55)
# - 아직 지니 계수도 0.5로 0이 아님 - 계속 분할

# %%
from sklearn.tree import plot_tree

plt.figure(figsize=(10,7))
plot_tree(dt_clf, filled=True, feature_names=iris_data.feature_names)
plt.show()
# Out:
# [Text(0.375, 0.875, 'petal length (cm) <= 2.45\ngini = 0.667\nsamples = 120\nvalue = [41, 40, 39]'),
#  Text(0.25, 0.625, 'gini = 0.0\nsamples = 41\nvalue = [41, 0, 0]'),
#  Text(0.3125, 0.75, 'True  '),
#  Text(0.5, 0.625, 'petal width (cm) <= 1.55\ngini = 0.5\nsamples = 79\nvalue = [0, 40, 39]'),
#  Text(0.4375, 0.75, '  False'),
#  Text(0.25, 0.375, 'petal length (cm) <= 5.25\ngini = 0.051\nsamples = 38\nvalue = [0, 37, 1]'),
#  Text(0.125, 0.125, 'gini = 0.0\nsamples = 37\nvalue = [0, 37, 0]'),
#  Text(0.375, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.75, 0.375, 'petal width (cm) <= 1.75\ngini = 0.136\nsamples = 41\nvalue = [0, 3, 38]'),
#  Text(0.625, 0.125, 'gini = 0.5\nsamples = 4\nvalue = [0, 2, 2]'),
#  Text(0.875, 0.125, 'gini = 0.053\nsamples = 37\nvalue = [0, 1, 36]')]

# %% [markdown]
# #### 각 노드 색상은 붓꽃 데이터의 레이블 값 의미
# - 주황색 : 0 setosa
# - 초록색 : 1 versicolor
# - 보라색 : 2 virginica
# - 색상이 짙을수록 지니 계수가 낮고
# - 해당 레이블에 속하는 샘플 데이터가 많다는 의미

# %% [markdown]
# ### 결정 트리 하이퍼 파라미터 튜닝

# %% [markdown]
# #### 결정 트리 하이퍼 파라미터
#
# - 규칙 트리는 규칙 생성 로직을 미리 제어하지 않으면
# - 완벽하게 클래스 값을 구별해 내기 위해
# - 트리 노드를 계속해서 만들어가기 때문에
# - 매우 복잡한 규칙 트리가 만들어져
# - **모델이 쉽게 과적합되는 문제 발생**
# - 하이퍼 파라미터를 사용하여 복잡한 트리가 생성되지 않도록 제어
#     - 여러 개의 하이퍼파라미터 값을 조절해서
#     - 트리의 깊이를 조절하여 (더 짦은 트리가 만들어지도록 / 너무 깊은 트리가 생성되지 않도록)
#     - 최적의 성능을 내도록 제어
#     --> 하이퍼 파리머터 튜닝 수행

# %% [markdown]
# #### 결정 트리의 하이퍼 파라미터
# - max_depth : 결정 트리의 최대 트리 깊이 제어
# - min_samples_split : 자식 규칙 노드를 분할해서 만드는데 필요한 최소 샘플 데이터 개수
#     - min_samples_split=4로 설정하는 경우
#     - 최소 샘플 개수가 4개 필요한데 (4개 이상이 되어야 분할할 자격이 생긴다)
#     - 3개만 있는 경우에는 더 이상 자식 규칙 노드를 위한 분할을 하지 않음
#     - 트리 깊이도 줄어서 더 간결한 결정 트리 생성
# - min_samples_leaf : 리프 노드가 될 수 있는 최소 샘플 개수
#     - 리프 노드가 될 수 있는 조건은 디폴트로 1
#     - 즉, 다른 클래스 값이 하나도 없이 단독 클래스로만 되어 있거나
#     - 단 한 개의 데이터로 되어 있을 경우에 리프 노드가 될 수 있다는 것
#     - min_samples_leaf 값을 키우면 더 이상 분할하지 않고,
#     - 리프 노드가 될 수 있는 조건이 완화됨
#     - min_samples_leaf=4로 설정하면
#     - 샘플이 최소 4개가 되어야 리프 노드가 되기 때문에
#     - 3개, 2개, 1개인 경우에는 리프 노드가 될 수 없으므로
#     - 더 이상 자식 규칙 노드를 위한 분할을 하지 않음
#     - 지니 계수가 크더라도 샘플이 4인 조건으로 규칙 변경되어
#     - 브랜치 노드가 줄어들고 결정 트리가 더 간결하게 됨

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 하이퍼 파라미터
# - 머신러닝 모델 훈련(학습)을 관리하는 데 사용하는 외부 구성 변수로
# - 모델 구조나 기능, 성능을 직접 제어
# - 사용자가 직접 값을 설정하는 파라미터
#
# #### 하이퍼 파라미터 튜닝
# - 하이퍼 파라미터의 기본 규칙이나 최적화된 값, 기본값이 미리 설정되어 있는 것이 아니기 때문에
# - 다양한 하이퍼 파라미터 세트를 사용하여 모델을 순차적으로 훈련시켜서
# - 적절한 하이퍼 파라미터 값을 선택하는 것이 중요
# - 하이퍼 파라미터 튜닝 프로세스는 반복적으로 파라미터와 값의 다양한 조합 시도
# - 성능이 최적이 되는 하이퍼 파라미터 값을 찾음

# %% [markdown]
# #### GridSearchCV 클래스를 이용해 하이퍼 파라미터 튜닝
# - 사이킷런 model_selection 패키지의 GridSearchCV 클래스 사용
# - 머신러닝에서 모델의 성능향상을 위해 쓰이는 기법중 하나
# - 시간이 오래걸린다는 단점
#
# #### 그리드 서치
# - 가능한 모든 조합을 통해 작동하여 가장 적합한 것을 결정
# - 파라미터 수가 많지 않을 때 적합
# - 하이퍼 파라미터 수가 많을 경우 경우의 수가 많아져서 데이터가 크면 파라미터 튜닝에 시간이 오래 걸림
#
# #### 랜덤 서치(Random search)
# - 그리드 서치(Grid search)와 유사한 원리이지만
# - 각 반복에서 랜덤하게 하이퍼파라미터 그룹 선택
# - 랜덤하게 일부의 파라미터들만 관측한 후, 그 중에서 가장 좋은 파라미터 선택
# - Grid Search에 비해 불필요한 반복 수행 횟수를 줄일 수 있어 수행 속도 빠름

# %%
# 결정 트리 하이퍼 파라미터 튜닝1
# 모델 생성 시 하이퍼 파라미터 설정 : max_depth

from sklearn.tree import DecisionTreeClassifier

# Classifier(분류기/모델) 생성 시 max_depth 설정
# max_depth=3 : max_depth가 3인 트리로 생성 
dt_clf = DecisionTreeClassifier(max_depth=3, random_state=156)
dt_clf.fit(X_train, y_train)

plt.figure(figsize=(10,7))
plot_tree(dt_clf, filled=True, feature_names=iris_data.feature_names)
plt.show()
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=156)
# [Text(0.375, 0.875, 'petal length (cm) <= 2.45\ngini = 0.667\nsamples = 120\nvalue = [41, 40, 39]'),
#  Text(0.25, 0.625, 'gini = 0.0\nsamples = 41\nvalue = [41, 0, 0]'),
#  Text(0.3125, 0.75, 'True  '),
#  Text(0.5, 0.625, 'petal width (cm) <= 1.55\ngini = 0.5\nsamples = 79\nvalue = [0, 40, 39]'),
#  Text(0.4375, 0.75, '  False'),
#  Text(0.25, 0.375, 'petal length (cm) <= 5.25\ngini = 0.051\nsamples = 38\nvalue = [0, 37, 1]'),
#  Text(0.125, 0.125, 'gini = 0.0\nsamples = 37\nvalue = [0, 37, 0]'),
#  Text(0.375, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.75, 0.375, 'petal width (cm) <= 1.75\ngini = 0.136\nsamples = 41\nvalue = [0, 3, 38]'),
#  Text(0.625, 0.125, 'gini = 0.5\nsamples = 4\nvalue = [0, 2, 2]'),
#  Text(0.875, 0.125, 'gini = 0.053\nsamples = 37\nvalue = [0, 1, 36]')]

# %%
# 결정 트리 하이퍼 파라미터 튜닝2
# 모델 생성 시 하이퍼 파라미터 설정 : min_samples_split

# 분할 가능한 최소 샘플 수를 4로 설정 (분할 조건 : 분할 자격 샘플 수)
# min_samples_split=4로 설정
dt_clf = DecisionTreeClassifier(min_samples_split=4, random_state=156)
dt_clf.fit(X_train, y_train)

plt.figure(figsize=(10,7))
plot_tree(dt_clf, filled=True, feature_names=iris_data.feature_names)
plt.show()

# 최소 4개는 되어야 분할 가능
# 지니계수가 0이 아니고, 섞여 있더라도 더 이상 분할 못함 
# 트리 생성 중단 (트리를 짧게 만듦)
# 과적합 방지 -> 일반화 성능 향상
# Out:
# DecisionTreeClassifier(min_samples_split=4, random_state=156)
# [Text(0.3181818181818182, 0.9, 'petal length (cm) <= 2.45\ngini = 0.667\nsamples = 120\nvalue = [41, 40, 39]'),
#  Text(0.22727272727272727, 0.7, 'gini = 0.0\nsamples = 41\nvalue = [41, 0, 0]'),
#  Text(0.2727272727272727, 0.8, 'True  '),
#  Text(0.4090909090909091, 0.7, 'petal width (cm) <= 1.55\ngini = 0.5\nsamples = 79\nvalue = [0, 40, 39]'),
#  Text(0.36363636363636365, 0.8, '  False'),
#  Text(0.18181818181818182, 0.5, 'petal length (cm) <= 5.25\ngini = 0.051\nsamples = 38\nvalue = [0, 37, 1]'),
#  Text(0.09090909090909091, 0.3, 'gini = 0.0\nsamples = 37\nvalue = [0, 37, 0]'),
#  Text(0.2727272727272727, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.6363636363636364, 0.5, 'petal width (cm) <= 1.75\ngini = 0.136\nsamples = 41\nvalue = [0, 3, 38]'),
#  Text(0.45454545454545453, 0.3, 'sepal length (cm) <= 5.45\ngini = 0.5\nsamples = 4\nvalue = [0, 2, 2]'),
# ...

# %%
# 결정 트리 하이퍼 파라미터 튜닝3
# 모델 생성 시 하이퍼 파라미터 설정 : min_samples_leaf

# 리프 노드가 될 수 있는 최소 샘플 수 설정 (분할 조건 : 분할 자격 샘플 수)
# min_samples_leaf=4로 설정 (최소 4개는 있어야지 리프 노드가 될 수 있음)

dt_clf = DecisionTreeClassifier(min_samples_leaf=4, random_state=156)
dt_clf.fit(X_train, y_train)

plt.figure(figsize=(10,7))
plot_tree(dt_clf, filled=True, feature_names=iris_data.feature_names)
plt.show()

# 말단 노드가 되기 위해서는 최소 4개는 있어야 함
# 현재 노드를 분할해서 샘플 수가 4보다 작으면 분할 못함
# Out:
# DecisionTreeClassifier(min_samples_leaf=4, random_state=156)
# [Text(0.3333333333333333, 0.9, 'petal length (cm) <= 2.45\ngini = 0.667\nsamples = 120\nvalue = [41, 40, 39]'),
#  Text(0.2222222222222222, 0.7, 'gini = 0.0\nsamples = 41\nvalue = [41, 0, 0]'),
#  Text(0.2777777777777778, 0.8, 'True  '),
#  Text(0.4444444444444444, 0.7, 'petal width (cm) <= 1.55\ngini = 0.5\nsamples = 79\nvalue = [0, 40, 39]'),
#  Text(0.38888888888888884, 0.8, '  False'),
#  Text(0.2222222222222222, 0.5, 'petal length (cm) <= 4.75\ngini = 0.051\nsamples = 38\nvalue = [0, 37, 1]'),
#  Text(0.1111111111111111, 0.3, 'gini = 0.0\nsamples = 34\nvalue = [0, 34, 0]'),
#  Text(0.3333333333333333, 0.3, 'gini = 0.375\nsamples = 4\nvalue = [0, 3, 1]'),
#  Text(0.6666666666666666, 0.5, 'petal width (cm) <= 1.75\ngini = 0.136\nsamples = 41\nvalue = [0, 3, 38]'),
#  Text(0.5555555555555556, 0.3, 'gini = 0.5\nsamples = 4\nvalue = [0, 2, 2]'),
# ...

# %%
# max_leaf_nodes=4로 설정
dt_clf = DecisionTreeClassifier(max_leaf_nodes=4, random_state=156)
dt_clf.fit(X_train, y_train)

plt.figure(figsize=(10,7))
plot_tree(dt_clf, filled=True, feature_names=iris_data.feature_names)
plt.show()
# Out:
# DecisionTreeClassifier(max_leaf_nodes=4, random_state=156)
# [Text(0.4, 0.875, 'petal length (cm) <= 2.45\ngini = 0.667\nsamples = 120\nvalue = [41, 40, 39]'),
#  Text(0.2, 0.625, 'gini = 0.0\nsamples = 41\nvalue = [41, 0, 0]'),
#  Text(0.30000000000000004, 0.75, 'True  '),
#  Text(0.6, 0.625, 'petal width (cm) <= 1.55\ngini = 0.5\nsamples = 79\nvalue = [0, 40, 39]'),
#  Text(0.5, 0.75, '  False'),
#  Text(0.4, 0.375, 'petal length (cm) <= 5.25\ngini = 0.051\nsamples = 38\nvalue = [0, 37, 1]'),
#  Text(0.2, 0.125, 'gini = 0.0\nsamples = 37\nvalue = [0, 37, 0]'),
#  Text(0.6, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.8, 0.375, 'gini = 0.136\nsamples = 41\nvalue = [0, 3, 38]')]

# %% [markdown]
# ### 분류기(dt_clf)의 feature_importance_ 속성

# %% [markdown]
# #### feature_importance_ 속성 : 피처 중요도 속성
# - tree를 만드는 결정(분할할 때)에 각 피처가 얼마나 중요한지 평가하는 수치
# - 0~1 사이의 숫자
# ---
# - 결정 트리는 균일도에 기반해서 어떠한 속성(피처)를 규칙 조건으로 선택하느냐가 중요한 요건
# - 중요한 몇 개의 피처가 명확한 규칙 트리를 만드는데 크게 기여하며
# - 모델을 좀 더 간결하고 이상치에 강한 모델을 만들 수 있음
# ---
# feature_importances_
# - ndarray 형태로 값을 반환
# - 피처 순서대로 값이 할당됨
# - [첫 번째 피처의 중요도, 두 번째 피처의 중요도, ....]
# - 값이 높을 수록 해당 피처의 중요도가 높다는 의미
# - 특정 노드의 중요도 값이 클수록, 그 노드에서 불순도가 크게 감소 의미

# %%
# 피처별 중요도 값 확인하고 막대 그래프로 표현
# 위에서 학습한(fit()) 객체(모델/분류기) df_clf의 
# feature_importances_ 속성 사용

# 피처 이름
iris_data.feature_names

# 피처별 중요도 (모델에서 피처 중요도)
dt_clf.feature_importances_

# petal length (cm) : 0.5459484
# petal width (cm) : 0.44810433
# sepal length (cm) : 0.00594727
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']
# array([0.        , 0.        , 0.57021885, 0.42978115])

# %%
# featuure 별 importance 맵핑
for name, value in zip(iris_data.feature_names, dt_clf.feature_importances_):
    print(f"{name} : {value:.3f}")
# Out:
# sepal length (cm) : 0.000
# sepal width (cm) : 0.000
# petal length (cm) : 0.570
# petal width (cm) : 0.430

# %%
import seaborn as sns
# feature_importances_를 컬럼 별로 시각화
sns.barplot(x=iris_data.feature_names, y=dt_clf.feature_importances_)
plt.show()
# Out:
# <Axes: >

# %% [markdown]
# ### 결정 트리 과적합 (Overfitting)

# %% [markdown]
# #### 결정 트리 과적합 (Overfitting)
# - 과적합 : ML에서 학습 데이터를 과하게 학습하는 것
# - 과적합 문제 : 학습 데이터에서는 정확하지만 테스트 데이터에서는 성과가 나쁜 현상
# - 의사결정 트리 과적합 : 나무의 크기가 크거나 가지의 수가 많을 때 과적합 문제 발생
# ---
# - 과소적합 (Underfitting)
#     - 학습이 제대로 이루어지지 않은 상태
#     - 데이터가 불충분하거나 모델이 지나치게 단순하여 학습량이 충분치 않을 경우
# ---
# #### 머신러닝 모델 학습 목표
# - 다양한 데이터에 대해 적용할 수 있는 일반적인 모델을 만드는 것

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 과적합이 발생하는 경우
# - 데이터가 충분하지 못한  경우
# - 데이터는 적은데 피쳐수는 많은 경우
# - 데이터의 분산이 크거나 노이즈(관련성이 없거나 무의미한 데이터, 오류가 많은 데이터 등)가 심한 경우
# - 모델의 복잡도가 큰 경우 : 변수 종류와 개수가 많거나, 앙상블에서 모델 개수가 많은 경우
#
# 과적합을 방지하기 위한 방법
# - 데이터를 늘리거나 피처 수를 줄이면 되는데
# - (피처 수  줄일 때 : 피처 중요도 활용 )
# - 데이터가 없으면 어려움
# - 그래서 피처에 패널티(규제)를 부여해서 영향력을 조정
