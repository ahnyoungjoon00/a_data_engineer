# %% [markdown]
# # 분류 실습 : 캐글 신용카드 사기 검출

# %% [markdown]
# Kaggle의 신용카드 데이터 세트를 이용해 신용카드 사기 검출 분류 실습
# 데이터 다운로드 : www.kaggle.com에서 검색
# credit card fraud

# %% [markdown]
# 신용카드 데이터 세트 특징
# - 2013년 European Card 사용 트랜잭션을 가공해서 생성
# - 불균형(Imbalanced)되어 있는 데이터 셋 284,807건의 데이터 중 492건이 Fraud(사기)
#
# 레이블인 Class 속성이 매우 불균형한 분포
# - 0 값 : 정상 트랜잭선
# - 1 값 : 사기 트랜잭션 (0.172 %)
#
# 일반적인 사기 검출(Fraud Detection)이나 이상 검출(Anomaly Detection)과 같은 데이터 세트는
# 레이블 값이 극도로 불균형한 분포를 이룸
# 사기와 같은 이상 현상은 전체 데이터에서 차지하는 비중이 매우 적기 때문

# %% [markdown]
# Credit Card Falut Detection ML 모델 구축
# - 다양한 Feature Engineering 방식을
# - Logistic Regression 알고리즘 이용

# %% [markdown]
# Feature Engineering
# - 피처들 중 어떤 것이 모델링할 때 중요한 것인지 결정하는 과정
# - 모델 성능에 미치는 영향이 크기 때문에 머신러닝 응용에 있어서 굉장히 중요한 단계이며
# - 전문성과 시간과 비용이 많이 드는 작업
# - PCA 방식 사용
#
# PCA(Principal Component Analysis)
# - 대표적인 차원 축소 알고리즘
# - 여러 변수 간 존재하는 상관관계를 이용해 차원을 축소하는 기법
# - 간단하게 가장 높은 분산을 가지는 데이터의 축을 찾아 차원을 축소
#
# 차원 축소
# - 많은 피처로 구성된 다차원의 데이터 셋을
# - 차원을 축소하여 새로원 차원의 데이터 세트를 생성하는 것

# %% [markdown]
# Feature Engineering 주요 작업
# - 주요 Feature의 데이터 분포도 변경
#     - Log 변환
# - 이상치(Outlier) 제거
# - SMOTE 오버 샘플링

# %% [markdown]
# ### 언더 샘플링과 오버 샘플링
# - **레이블**이 불균형한 분포를 가진 데이터 세트를 학습 시 예측 성능의 문제 발생
# - 이상 레이블을 가지는 데이터 건수가 정상 레이블을 가진 데이터 건수에 비해 너무 적어
# - 다양한 유형을 학습하지 못하고 일방적으로 너무 많은 정상 레이블로 치우친 학습을 수행하게되는 문제

# %% [markdown]
# 오버 샘플링
# - 적은 레이블을 가진 데이터 세트를 많은 데이터 세트 수준으로 증식시키는 방식
#
#
# 언더 샘플링
# - 많은 레이블을 가진 데이터 세트를 적은 데이터 세트 수준으로 감소시키는 방식

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# SMOTE(Synthetic Minority Over-sample Technique)
# - 적은 데이터 세트에 있는 개별 데이터들의 K 최근접 이웃(K Nearest Neighbor)을 찾음
# - K개 이웃들과의 차이를 일정 값으로 만들어 기존 데이터와 약간 차이가 나는 새로운 데이터 생성 방식

# %% [markdown]
# SMOTE 수행 절차

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 신용카드 사기 검출 예제

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"

# import matplotlib.pyplot as plt
# import warnings

import pandas as pd
import numpy as np 
warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# ### 데이터 준비

# %%
card_df = pd.read_csv('./data/creditcard.csv')
card_df.head(3)

# Time : 크게 의미 있는 칼럼은 아님 데이터 만드는데 걸리는 시간 - 나중에 삭제
# v1~v28 속성 : 피처 이름이 전혀 들어가 있지 않음
# kaggle에서 칼럼 확인해보면
# 민감한 정보를 보호하기 위해서 PCA로 압축한 속성
# Amount : 카드 사용액
# Class : 0은 정상 사용, 1은 부정 카드 사용
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
#
# [3 rows x 31 columns]

# %%
# Out:
# (284807, 31)

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
# 불필요한 Time 열 삭제 후 원본 복사해서 사용

# %% [markdown]
# ### 데이터 세트 분리 함수 /  성능 평가 함수 사용

# %% [markdown]
# #### 데이터 세트 분리 함수

# %%
from sklearn.model_selection import train_test_split

# 분리된 학습과 테스트 데이터 세트를 반환하는 함수
def get_train_test_dataset(df):
    # DataFrame의 맨 마지막 컬럼이 레이블, 나머지는 피처들
    feature_data = df.iloc[:, :-1] # 피처 : 마지막 칼럼 전까지
    target_data = df.iloc[:, -1] # 레이블 : 마지막 칼럼
    
    # 데이터 세트 분리
    X_train, X_test, y_train, y_test = train_test_split(feature_data, 
                                                        target_data, 
                                                        test_size=0.3, 
                                                        random_state=0, 
                                                        stratify=target_data)
    
    # 학습과 테스트 데이터 세트 반환
    return X_train, X_test, y_train, y_test

# %%
# 데이터 세트 분리해주는 함수 호출하고 분리된 데이터 셋 받음
X_train, X_test, y_train, y_test = get_train_test_dataset(df_copy)

print('학습 데이터 레이블 값 비율')
y_train.value_counts()
print(y_train.value_counts(normalize=True) * 100)
print('테스트 데이터 레이블 값 비율')
print(y_test.value_counts(normalize=True) * 100)
# Out:
# 학습 데이터 레이블 값 비율
# Class
# 0    199020
# 1       344
# Name: count, dtype: int64
# Class
# 0    99.827451
# 1     0.172549
# Name: proportion, dtype: float64
# 테스트 데이터 레이블 값 비율
# Class
# 0    99.826785
# 1     0.173215
# Name: proportion, dtype: float64

# %% [markdown]
# #### 예측 모델 평가 수행 및 평가 지표 출력하는 함수

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import roc_auc_score


# 예측 모델 평가 수행 및 평가 지표 출력하는 함수  앞에서 복사할 것)
def get_clf_eval(y_test, y_pred, pred_proba) :
    cm = confusion_matrix(y_test, y_pred) # 혼동행렬(오차행렬)
    accuracy = accuracy_score(y_test, y_pred) # 정확도
    precision = precision_score(y_test, y_pred) # 정밀도
    recall = recall_score(y_test, y_pred)# 재현율
    f1 = f1_score(y_test, y_pred) # F1 스코어
    roc_auc = roc_auc_score(y_test, pred_proba) # ROC_AUC 스코어
    
    # 출력 
    # 오차행렬
    print("오차행렬 : ", cm)
    # 정확도, 정밀도, 재현율, F1
    print(f"정확도: {accuracy:.4f}, 정밀도: {precision:.4f}, 재현율: {recall:.4f}, F1 Score: {f1:.4f}, ROC_AUC : {roc_auc:.4f}")

# %% [markdown]
# ### LogisticRegression  학습/예측/평가 수행

# %%
from sklearn.linear_model import LogisticRegression

# 데이터 세트 분리 함수 호출
X_train, X_test, y_train, y_test = get_train_test_dataset(df_copy)


# 모델 생성 


# 평가




# 오차행렬 :  [[85282    13]
#  [   58    90]]
# 정확도: 0.9992, 정밀도: 0.8738, 재현율: 0.6081, F1 Score: 0.7171, ROC_AUC : 0.9709
# Out:
# LogisticRegression(solver='liblinear')
# 오차행렬 :  [[85282    13]
#  [   58    90]]
# 정확도: 0.9992, 정밀도: 0.8738, 재현율: 0.6081, F1 Score: 0.7171, ROC_AUC : 0.9708

# %% [markdown]
# ### 중요 데이터 분포도 변환 후 모델 학습/예측/평가

# %% [markdown]
# - Amount 피처는 신용 카드 사용 금액으로
# - 정상/사기 트랜잭션을 결정하는 중요 속성일 가능성 높음
# - 다른 피처들은 PCA 압축한 속성

# %%
# Out:
# count    284807.000000
# mean         88.349619
# std         250.120109
# min           0.000000
# 25%           5.600000
# 50%          22.000000
# 75%          77.165000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
# 중요 속성으로 Amount 선정해서 분포도 확인

import seaborn as sns

plt.figure(figsize=(8, 4))
plt.xticks(range(0, 30000, 1000), rotation=60)

plt.show()
# Out:
# ([<matplotlib.axis.XTick at 0x202bdd1f3e0>,
#   <matplotlib.axis.XTick at 0x202bf03ce30>,
#   <matplotlib.axis.XTick at 0x202bf022cf0>,
#   <matplotlib.axis.XTick at 0x202befe7d10>,
#   <matplotlib.axis.XTick at 0x202bf59ca40>,
#   <matplotlib.axis.XTick at 0x202bf59d310>,
#   <matplotlib.axis.XTick at 0x202bf59dbe0>,
#   <matplotlib.axis.XTick at 0x202bf59e5a0>,
#   <matplotlib.axis.XTick at 0x202bf59d4f0>,
#   <matplotlib.axis.XTick at 0x202bf59ec00>,
#   <matplotlib.axis.XTick at 0x202bf59f530>,
#   <matplotlib.axis.XTick at 0x202bf59fe30>,
#   <matplotlib.axis.XTick at 0x202bf580770>,
#   <matplotlib.axis.XTick at 0x202bf59ee10>,
#   <matplotlib.axis.XTick at 0x202bf580e60>,
#   <matplotlib.axis.XTick at 0x202bf5817f0>,
#   <matplotlib.axis.XTick at 0x202bf582150>,
#   <matplotlib.axis.XTick at 0x202bf582ae0>,
#   <matplotlib.axis.XTick at 0x202bf582870>,
#   <matplotlib.axis.XTick at 0x202bf583140>,
#   <matplotlib.axis.XTick at 0x202bf583aa0>,
#   <matplotlib.axis.XTick at 0x202bf5604a0>,
#   <matplotlib.axis.XTick at 0x202bf560dd0>,
#   <matplotlib.axis.XTick at 0x202bf561700>,
#   <matplotlib.axis.XTick at 0x202bf581a00>,
#   <matplotlib.axis.XTick at 0x202bf561d60>,
#   <matplotlib.axis.XTick at 0x202bf5626f0>,
#   <matplotlib.axis.XTick at 0x202bf562ff0>,
#   <matplotlib.axis.XTick at 0x202bf563950>,
#   <matplotlib.axis.XTick at 0x202bf563350>],
#  [Text(0, 0, '0'),
#   Text(1000, 0, '1000'),
#   Text(2000, 0, '2000'),
#   Text(3000, 0, '3000'),
#   Text(4000, 0, '4000'),
#   Text(5000, 0, '5000'),
#   Text(6000, 0, '6000'),
#   Text(7000, 0, '7000'),
#   Text(8000, 0, '8000'),
#   Text(9000, 0, '9000'),
#   Text(10000, 0, '10000'),
#   Text(11000, 0, '11000'),
#   Text(12000, 0, '12000'),
#   Text(13000, 0, '13000'),
#   Text(14000, 0, '14000'),
#   Text(15000, 0, '15000'),
#   Text(16000, 0, '16000'),
#   Text(17000, 0, '17000'),
#   Text(18000, 0, '18000'),
#   Text(19000, 0, '19000'),
#   Text(20000, 0, '20000'),
#   Text(21000, 0, '21000'),
#   Text(22000, 0, '22000'),
#   Text(23000, 0, '23000'),
#   Text(24000, 0, '24000'),
#   Text(25000, 0, '25000'),
#   Text(26000, 0, '26000'),
#   Text(27000, 0, '27000'),
#   Text(28000, 0, '28000'),
#   Text(29000, 0, '29000')])
# <Axes: xlabel='Amount', ylabel='Density'>

# %% [markdown]
# ####  Amount 피처에 표준 스케일링 적용

# %%
from sklearn.preprocessing import StandardScaler

df_copy = card_df.copy()

# %%
df_copy.head(2)
# Out:
#    Amount_Scaled        V1        V2        V3        V4        V5        V6  \
# 0       0.244964 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1      -0.342475  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
#
#          V7        V8        V9  ...       V21       V22       V23       V24  \
# 0  0.239599  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928
# 1 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846
#
#         V25       V26       V27       V28  Amount  Class
# 0  0.128539 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.167170  0.125895 -0.008983  0.014724    2.69      0
#
# [2 rows x 31 columns]

# %% [markdown]
# ### Amount 값 스케일링 후 모델 학습/예측/평가

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score 

def get_clf_eval(y_test, y_pred, pred_proba) :
    cm = confusion_matrix(y_test, y_pred) # 혼동행렬(오차행렬)
    accuracy = accuracy_score(y_test, y_pred) # 정확도
    precision = precision_score(y_test, y_pred) # 정밀도
    recall = recall_score(y_test, y_pred)# 재현율
    f1 = f1_score(y_test, y_pred) # F1 스코어
    roc_auc = roc_auc_score(y_test, pred_proba) # ROC_AUC 스코어
    
    # 출력 
    # 오차행렬
    print("오차행렬 : ", cm)
    # 정확도, 정밀도, 재현율, F1
    print(f"정확도: {accuracy:.4f}, 정밀도: {precision:.4f},  재현율: {recall:.4f}, F1 Score: {f1:.4f}, ROC_AUC : {roc_auc:.4f}")

# %%
# 로지스틱 회귀 
from sklearn.linear_model import LogisticRegression

print('로지스틱 회귀 예측 성능')
# 데이터 세트 분리 함수 호출
X_train, X_test, y_train, y_test = get_train_test_dataset(df_copy)

# 모델 생성
lr_clf = LogisticRegression(solver='liblinear')
lr_clf.fit(X_train, y_train)
y_pred = lr_clf.predict(X_test)

pred_proba = lr_clf.predict_proba(X_test)[:, 1]

get_clf_eval(y_test, y_pred, pred_proba)

# 스케일링 적용 전 
# 오차행렬 :  [[85282    13]
#  [   58    90]]
# 정확도: 0.9992, 정밀도: 0.8738, 재현율: 0.6081, F1 Score: 0.7171, ROC_AUC : 0.9709

# 스케일링 적용 후
# 오차행렬 :  [[85280    15]
#  [   59    89]]
# 정확도: 0.9991, 정밀도: 0.8558,  재현율: 0.6014, F1 Score: 0.7063, ROC_AUC : 0.9659

# 스케일링 전/후 별 차이 없음
# 아직도 재현율이 만족스럽지 못함
# Out:
# 로지스틱 회귀 예측 성능
# LogisticRegression()
# 오차행렬 :  [[85282    13]
#  [   57    91]]
# 정확도: 0.9992, 정밀도: 0.8750,  재현율: 0.6149, F1 Score: 0.7222, ROC_AUC : 0.9653

# %% [markdown]
# #### Amount를 로그 변환

# %%
df_copy = card_df.copy()

# %%
df_copy.head(2)
# Out:
#    Amount_Log        V1        V2        V3        V4        V5        V6  \
# 0    5.014760 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1    1.305626  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
#
#          V7        V8        V9  ...       V21       V22       V23       V24  \
# 0  0.239599  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928
# 1 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846
#
#         V25       V26       V27       V28  Amount  Class
# 0  0.128539 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.167170  0.125895 -0.008983  0.014724    2.69      0
#
# [2 rows x 31 columns]

# %% [markdown]
# ### 로그변환 후 모델링

# %%
# 로지스틱 회귀 
from sklearn.linear_model import LogisticRegression

print('로지스틱 회귀 예측 성능')
# 데이터 세트 분리 함수 호출
X_train, X_test, y_train, y_test = get_train_test_dataset(df_copy)

# 모델 생성
lr_clf = LogisticRegression(solver='liblinear')
lr_clf.fit(X_train, y_train)
y_pred = lr_clf.predict(X_test)

pred_proba = lr_clf.predict_proba(X_test)[:, 1]

get_clf_eval(y_test, y_pred, pred_proba)

## 로그변환 전
# 스케일링 적용 전 
# 오차행렬 :  [[85282    13]
#  [   58    90]]
# 정확도: 0.9992, 정밀도: 0.8738, 재현율: 0.6081, F1 Score: 0.7171, ROC_AUC : 0.9709

# 스케일링 적용 후
# 오차행렬 :  [[85280    15]
#  [   59    89]]
# 정확도: 0.9991, 정밀도: 0.8558,  재현율: 0.6014, F1 Score: 0.7063, ROC_AUC : 0.9659


## 로그변환 후
# 오차행렬 :  [[85271    24]
#  [   51    97]]
# 정확도: 0.9991, 정밀도: 0.8017,  재현율: 0.6554, F1 Score: 0.7212, ROC_AUC : 0.9346

# 로그 변환 후 재현율이 약간 상승했지만 아직도 만족스러운 수치는 아니라고 판단
# Out:
# 로지스틱 회귀 예측 성능
# LogisticRegression()
# 오차행렬 :  [[85276    19]
#  [   53    95]]
# 정확도: 0.9992, 정밀도: 0.8333,  재현율: 0.6419, F1 Score: 0.7252, ROC_AUC : 0.9361

# %% [markdown]
# ### 이상치 데이터 제거 후 모델 학습/예측/평가

# %% [markdown]
# - 각 피처들의 상관 관계를 시각화
# - 결정 레이블인 class 값과 가장 상관도가 높은 피처 추출
# - 상관도가 높은 피처들에 대해서 아웃 라이어(이상치) 찾아서
# - 이상치가 높은 피처들의 행 삭제

# %%
import seaborn as sns

plt.figure(figsize=(10, 10))

plt.show()



# Class 값과 상관도가 높은 피처를 찾아서 확인 : X축에서 v12, v14, v17 (짙은 빨간색)
# 이 중에서 v14에 해당되는 이상치를 찾아 확인해 볼 것
# Out:
# <Axes: >

# %% [markdown]
# ### IQR을 이용해 이상치 데이터 검출
# - IQR*1.5해서 최대값과 최소값 결정
# - 이상치 : 최대값 초과 또는 최소값 미만 데이터

# %%
# 이상치를 찾기 위한 함수 새로 생성

import numpy as np

# 전체 데이터에서 찾지 않고 사기 데이터 (Class가 1인)에서 찾음
# 최대, 최소값을 벗어난 값을 이상치로 간주하고 이상치 인덱스 찾아서 반환
def get_outlier(df=None, column=None, weight=1.5):

    
    return outlier_index

# %%
outlier_index = get_outlier(df=card_df, column='V14', weight=1.5)
print('이상치 데이터 인덱스:', outlier_index)
# 4개 인덱스 : 이 인덱스에 해당되는 행은 삭제할 것임
# Out:
# 이상치 데이터 인덱스: Index([8296, 8615, 9035, 9252], dtype='int64')

# %% [markdown]
# **로그 변환 후 V14 피처의 이상치 데이터를 삭제한 뒤 모델들을 재 학습/예측/평가**

# %%
df_copy = card_df.copy()

# 로그변환 


# 이상치 데이터 삭제
    
df_copy.head(3)
# Out:
#    Amount_log        V1        V2        V3        V4        V5        V6  \
# 0    5.014760 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1    1.305626  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2    5.939276 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
#
#          V7        V8        V9  ...       V21       V22       V23       V24  \
# 0  0.239599  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928
# 1 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.791461  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281
#
#         V25       V26       V27       V28  Amount  Class
# 0  0.128539 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.167170  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.327642 -0.139097 -0.055353 -0.059752  378.66      0
#
# [3 rows x 31 columns]

# %%
# 이상치 데이터 삭제

df_copy.head(3)
# Out:
#    Amount_log        V1        V2        V3        V4        V5        V6  \
# 0    5.014760 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1    1.305626  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2    5.939276 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
#
#          V7        V8        V9  ...       V21       V22       V23       V24  \
# 0  0.239599  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928
# 1 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.791461  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281
#
#         V25       V26       V27       V28  Amount  Class
# 0  0.128539 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.167170  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.327642 -0.139097 -0.055353 -0.059752  378.66      0
#
# [3 rows x 31 columns]

# %%
# 로지스틱 회귀 
from sklearn.linear_model import LogisticRegression

print('로지스틱 회귀 예측 성능')
# 데이터 세트 분리 함수 호출
X_train, X_test, y_train, y_test = get_train_test_dataset(df_copy)

# 모델 생성
lr_clf = LogisticRegression(solver='liblinear')
lr_clf.fit(X_train, y_train)
y_pred = lr_clf.predict(X_test)

pred_proba = lr_clf.predict_proba(X_test)[:, 1]

get_clf_eval(y_test, y_pred, pred_proba)

# 로그변환 후 이상치 제거 전
# 오차행렬 :  [[85271    24]
#  [   51    97]]
# 정확도: 0.9991, 정밀도: 0.8017,  재현율: 0.6554, F1 Score: 0.7212, ROC_AUC : 0.9346

# 로그변환 후 이상치 제거 후
# 오차행렬 :  [[85282    13]
#  [   54    91]]
# 정확도: 0.9992, 정밀도: 0.8750,  재현율: 0.6276, F1 Score: 0.7309, ROC_AUC : 0.9418

# 전체적으로 다른 지표는 약간 수치가 올랐지만 재현율은 약간 떨어짐 
# 재현율이 만족스럽지 못함
# Out:
# 로지스틱 회귀 예측 성능
# LogisticRegression()
# 오차행렬 :  [[85282    13]
#  [   52    93]]
# 정확도: 0.9992, 정밀도: 0.8774,  재현율: 0.6414, F1 Score: 0.7410, ROC_AUC : 0.9417

# %% [markdown]
# ### SMOTE 오버 샘플링 적용 후 모델 학습/예측/평가

# %% [markdown]
# - SMOTE 적용 시 **반드시 학습 데이터 세트만 오버 샘플링 수행**
# - 검증 데이터 세트나 테스트 데이터 세트를 오버 샘플링할 경우
#   - 결국 원본 데이터 세트가 아닌
#     - 변형된 데이터 세트에서 검증 또는 테스트를 수행하기 때문에
#     - 올바른 검증/테스트가 될 수 없음
# ---
# SMOTE 방식을 제공하는 패키지 : imblearn.over_sampling (imbalanced learn)
# imbalanced-learn 설치 필요

# %%
# !pip install -U imbalanced-learn

# %%
# 불균형 데이터를 다루기 위한 패키지 imblearn 설치
# imblearn 설치
# Anaconda Prompt에서
# 가상환경 활성화하고 : conda activate MLenv
# 설치 : pip install -U imbalanced-learn

# %%
import imblearn
imblearn.__version__
# Out:
# '0.12.4'

# %%
from imblearn.over_sampling import SMOTE

df_copy = card_df.copy()

# 데이터 세트 분리 함수 호출
X_train, X_test, y_train, y_test = get_train_test_dataset(df_copy)

# 오버 샘플링



# 전체 데이터 :284,807
# 테스트 : 30%, 학습 : 70% (199,364)
print('SMOT 적용 전 학습용 피처/레이블 데이터 세트: ', X_train.shape, y_train.shape)
print('SMOT 적용 후 학습용 피처/레이블 데이터 세트: ', X_train_over.shape, y_train_over.shape)
print('SMOT 적용 후 레이블 값 분포: ', pd.Series(y_train_over).value_counts())
# Out:
# SMOT 적용 전 학습용 피처/레이블 데이터 세트:  (199364, 29) (199364,)
# SMOT 적용 후 학습용 피처/레이블 데이터 세트:  (398040, 29) (398040,)
# SMOT 적용 후 레이블 값 분포:  Class
# 0    199020
# 1    199020
# Name: count, dtype: int64

# %%
# SMOT 적용 전 레이블 값 분포
y_train.value_counts()
# Out:
# Class
# 0    199020
# 1       344
# Name: count, dtype: int64

# %% [markdown]
# #### 로지스틱 회귀로 학습/예측/평가 **

# %%
# 오버샘플링 후 로지스틱 회귀 
from sklearn.linear_model import LogisticRegression

print('로지스틱 회귀 예측 성능')

# 모델 생성
lr_clf = LogisticRegression(solver='liblinear')
lr_clf.fit(X_train_over, y_train_over) # 오버샘플링된 데이터로 학습

y_pred = lr_clf.predict(X_test)
pred_proba = lr_clf.predict_proba(X_test)[:, 1]

get_clf_eval(y_test, y_pred, pred_proba)


# 오버샘플링 후 결과 
# 오차행렬 :  [[83945  1350]
#  [   16   132]]
# 정확도: 0.9840, 정밀도: 0.0891,  재현율: 0.8919, F1 Score: 0.1620, ROC_AUC : 0.980

# 재현율 (0.8919) : 무척 좋아졌음 
# 정밀도 (0.0891) : 엄청 떨어졌음 
# F1 Score (0.1620) : 재현율과 정밀도 불균형 

# 재현율이 높더라도 정밀도 너무 낮기 때문에 실제로는 사용할 수 없는 모듈로 판단 
# 오버샘플링으로 인해 원본 데이터보다 너무 많는 class=1 데이터를 학습하면서
# 실제 테스트 데이터 세트에 제대로 예측하지 못했음

# Precision-Recall 곡선에서 임계값에 따라 정밀도와 재현율의 조정이 가능한지 확인
# Out:
# 로지스틱 회귀 예측 성능
# LogisticRegression()
# 오차행렬 :  [[83935  1360]
#  [   16   132]]
# 정확도: 0.9839, 정밀도: 0.0885,  재현율: 0.8919, F1 Score: 0.1610, ROC_AUC : 0.9808

# %% [markdown]
# #### Precision-Recall 곡선 시각화 **

# %%
from sklearn.metrics import precision_recall_curve

def precision_recall_curve_plot(y_test, pred_proba): 
    precision, reacalls, thresholds = precision_recall_curve(y_test, pred_proba)
    
    threshold_boundary = thresholds.shape[0]
    # x축은 thresholds 값, y축은 정밀도, 재현율  값으로 plot() 
    plt.plot(thresholds, precision[0:threshold_boundary], 
             linestyle='--', label='precision')

    plt.plot(thresholds, reacalls[0:threshold_boundary], label='reacall')

    # thresholds 값 x축 : 0, 1 단위로 변경
    # xlim() : x축  범위 지정|
    start, end = plt.xlim()
    plt.xticks(np.round(np.arange(start, end, 0.1), 2))

    plt.xlabel('Thresholds Value')
    plt.ylabel('Precision and Recall Value')
    plt.legend()
    plt.grid()
    plt.show()

# %%
precision_recall_curve_plot(y_test, lr_clf.predict_proba(X_test)[:, 1] )

# %%
# Light GBM 설치
# Anaconda Prompt에서
# 가상환경 활성화하고 : conda activate MLenv
# 설치 : pip install lightgbm

# %%
# 불필요한 Time 열 삭제 후 원본 복사해서 사용
# card_df.drop('Time', axis=1, inplace=True)
# df_copy = card_df.copy()

X_train, X_test, y_train, y_test = get_train_test_dataset(df_copy)

# %% [markdown]
# #### LightGBM 모델 적용 **

# %%
# boost_from_average=False : 불균형한 데이터 세트에서 예측 성능이 매우 저조할 경우 
# LightGBM 객체 생성 시 boost_from_average = False로 파라미터를 설정
# True 값으로 설정할 경우 재현율과 roc_auc_score가 매우 낮아짐 

# force_col_wise=True
# 메모리 용량이 충분하지 않을 때 메모리 효율을 높이는 파라미터

# early_stopping : 조기 종료. 지정된 라운드 동안 성능 개선이 없으면 학습 중단  
# callbacks : 학습 중 자동으로 수행할 작업(함수) 지정
# log_evaluation : 로그 출력 콜백. 지정된 주기마다 평가지표 출력
# logloss: 분류 모델 평가 지표. 잘못 분류된 손실값(loss) 계산하는 함수
# eval_metrics: 평가 지표 지정 
# eval_set: 모델 학습 중 성능 평가를 위한 검증 데이터 세트 설정

# %%
card_df = pd.read_csv('./data/creditcard.csv')
card_df.drop('Time', axis=1, inplace=True)

# %%
# (1) 아무 것도 하지 않은 경우
# 로그변환 (X) / 이상치 제거 (X) / 오버샘플링 (X) / early_stopping(100) (X) 
from lightgbm import LGBMClassifier, early_stopping, log_evaluation

df_copy = card_df.copy()

X_train, X_test, y_train, y_test = get_train_test_dataset(df_copy)

print('LightGBM 예측 성능')



# 오차행렬 :  [[85291     4]
#  [   37   111]]
# 정확도: 0.9995, 정밀도: 0.9652,  재현율: 0.7500, F1 Score: 0.8441, ROC_AUC : 0.9805
# Out:
# LightGBM 예측 성능
# [LightGBM] [Info] Number of positive: 344, number of negative: 199020
# [LightGBM] [Info] Total Bins 7395
# [LightGBM] [Info] Number of data points in the train set: 199364, number of used features: 29
# [1]	valid_0's binary_logloss: 0.598339
# [2]	valid_0's binary_logloss: 0.520683
# [3]	valid_0's binary_logloss: 0.455938
# [4]	valid_0's binary_logloss: 0.401211
# [5]	valid_0's binary_logloss: 0.35447
# [6]	valid_0's binary_logloss: 0.314202
# [7]	valid_0's binary_logloss: 0.279286
# [8]	valid_0's binary_logloss: 0.248827
# [9]	valid_0's binary_logloss: 0.222144
# [10]	valid_0's binary_logloss: 0.198675
# [11]	valid_0's binary_logloss: 0.177951
# [12]	valid_0's binary_logloss: 0.159617
# [13]	valid_0's binary_logloss: 0.14334
# [14]	valid_0's binary_logloss: 0.128859
# [15]	valid_0's binary_logloss: 0.115959
# [16]	valid_0's binary_logloss: 0.104448
# [17]	valid_0's binary_logloss: 0.0941634
# [18]	valid_0's binary_logloss: 0.0849601
# [19]	valid_0's binary_logloss: 0.0767154
# [20]	valid_0's binary_logloss: 0.0693241
# [21]	valid_0's binary_logloss: 0.0626929
# [22]	valid_0's binary_logloss: 0.0567344
# [23]	valid_0's binary_logloss: 0.051376
# [24]	valid_0's binary_logloss: 0.0465581
# [25]	valid_0's binary_logloss: 0.042217
# [26]	valid_0's binary_logloss: 0.0383192
# [27]	valid_0's binary_logloss: 0.034802
# [28]	valid_0's binary_logloss: 0.03164
# [29]	valid_0's binary_logloss: 0.0287862
# [30]	valid_0's binary_logloss: 0.0262159
# [31]	valid_0's binary_logloss: 0.0238994
# [32]	valid_0's binary_logloss: 0.0218109
# [33]	valid_0's binary_logloss: 0.0199259
# [34]	valid_0's binary_logloss: 0.0182187
# [35]	valid_0's binary_logloss: 0.0166842
# [36]	valid_0's binary_logloss: 0.0153069
# [37]	valid_0's binary_logloss: 0.0140529
# [38]	valid_0's binary_logloss: 0.0129205
# [39]	valid_0's binary_logloss: 0.0119077
# [40]	valid_0's binary_logloss: 0.0109959
# [41]	valid_0's binary_logloss: 0.0101787
# [42]	valid_0's binary_logloss: 0.00943889
# [43]	valid_0's binary_logloss: 0.00875538
# [44]	valid_0's binary_logloss: 0.00815001
# [45]	valid_0's binary_logloss: 0.00761418
# [46]	valid_0's binary_logloss: 0.00712371
# [47]	valid_0's binary_logloss: 0.00668384
# [48]	valid_0's binary_logloss: 0.00628776
# [49]	valid_0's binary_logloss: 0.00593637
# [50]	valid_0's binary_logloss: 0.0056188
# [51]	valid_0's binary_logloss: 0.00532204
# [52]	valid_0's binary_logloss: 0.00506624
# [53]	valid_0's binary_logloss: 0.00482962
# [54]	valid_0's binary_logloss: 0.00462179
# [55]	valid_0's binary_logloss: 0.00443811
# [56]	valid_0's binary_logloss: 0.00426964
# [57]	valid_0's binary_logloss: 0.00412196
# [58]	valid_0's binary_logloss: 0.00399026
# [59]	valid_0's binary_logloss: 0.00387569
# [60]	valid_0's binary_logloss: 0.00377224
# [61]	valid_0's binary_logloss: 0.00369025
# [62]	valid_0's binary_logloss: 0.00360188
# [63]	valid_0's binary_logloss: 0.00351581
# [64]	valid_0's binary_logloss: 0.00349116
# [65]	valid_0's binary_logloss: 0.003429
# [66]	valid_0's binary_logloss: 0.00337779
# [67]	valid_0's binary_logloss: 0.00332428
# [68]	valid_0's binary_logloss: 0.00340632
# [69]	valid_0's binary_logloss: 0.0033539
# [70]	valid_0's binary_logloss: 0.00330979
# [71]	valid_0's binary_logloss: 0.00327847
# [72]	valid_0's binary_logloss: 0.00324773
# [73]	valid_0's binary_logloss: 0.00322398
# [74]	valid_0's binary_logloss: 0.00319037
# [75]	valid_0's binary_logloss: 0.00317138
# [76]	valid_0's binary_logloss: 0.00315509
# [77]	valid_0's binary_logloss: 0.00314223
# [78]	valid_0's binary_logloss: 0.00312835
# [79]	valid_0's binary_logloss: 0.00312032
# [80]	valid_0's binary_logloss: 0.00311583
# [81]	valid_0's binary_logloss: 0.00311706
# [82]	valid_0's binary_logloss: 0.00312171
# [83]	valid_0's binary_logloss: 0.00311573
# [84]	valid_0's binary_logloss: 0.00312312
# [85]	valid_0's binary_logloss: 0.00312583
# [86]	valid_0's binary_logloss: 0.0031278
# [87]	valid_0's binary_logloss: 0.00313874
# [88]	valid_0's binary_logloss: 0.00313908
# [89]	valid_0's binary_logloss: 0.00313856
# [90]	valid_0's binary_logloss: 0.00313784
# [91]	valid_0's binary_logloss: 0.00314099
# [92]	valid_0's binary_logloss: 0.00315163
# [93]	valid_0's binary_logloss: 0.00315756
# [94]	valid_0's binary_logloss: 0.00317677
# [95]	valid_0's binary_logloss: 0.00318715
# [96]	valid_0's binary_logloss: 0.00319147
# [97]	valid_0's binary_logloss: 0.00319896
# [98]	valid_0's binary_logloss: 0.00320854
# [99]	valid_0's binary_logloss: 0.00321222
# [100]	valid_0's binary_logloss: 0.00322149
# [101]	valid_0's binary_logloss: 0.00322323
# [102]	valid_0's binary_logloss: 0.00322981
# [103]	valid_0's binary_logloss: 0.00324455
# [104]	valid_0's binary_logloss: 0.0032573
# [105]	valid_0's binary_logloss: 0.00326322
# [106]	valid_0's binary_logloss: 0.00327535
# [107]	valid_0's binary_logloss: 0.003286
# [108]	valid_0's binary_logloss: 0.00330097
# [109]	valid_0's binary_logloss: 0.00331756
# [110]	valid_0's binary_logloss: 0.00332962
# [111]	valid_0's binary_logloss: 0.00333696
# [112]	valid_0's binary_logloss: 0.00335617
# [113]	valid_0's binary_logloss: 0.00337181
# [114]	valid_0's binary_logloss: 0.00339005
# [115]	valid_0's binary_logloss: 0.00339522
# [116]	valid_0's binary_logloss: 0.00340598
# [117]	valid_0's binary_logloss: 0.003424
# [118]	valid_0's binary_logloss: 0.00344285
# [119]	valid_0's binary_logloss: 0.00345466
# [120]	valid_0's binary_logloss: 0.00347426
# [121]	valid_0's binary_logloss: 0.00349045
# [122]	valid_0's binary_logloss: 0.0035137
# [123]	valid_0's binary_logloss: 0.00353583
# [124]	valid_0's binary_logloss: 0.00355503
# [125]	valid_0's binary_logloss: 0.00357152
# [126]	valid_0's binary_logloss: 0.00359447
# [127]	valid_0's binary_logloss: 0.00361847
# [128]	valid_0's binary_logloss: 0.00362677
# [129]	valid_0's binary_logloss: 0.00364231
# [130]	valid_0's binary_logloss: 0.0036535
# [131]	valid_0's binary_logloss: 0.00366971
# [132]	valid_0's binary_logloss: 0.00367239
# [133]	valid_0's binary_logloss: 0.00369262
# [134]	valid_0's binary_logloss: 0.0037133
# [135]	valid_0's binary_logloss: 0.00372962
# [136]	valid_0's binary_logloss: 0.0037452
# [137]	valid_0's binary_logloss: 0.00375706
# [138]	valid_0's binary_logloss: 0.00376916
# [139]	valid_0's binary_logloss: 0.00378767
# [140]	valid_0's binary_logloss: 0.00380712
# [141]	valid_0's binary_logloss: 0.00381779
# [142]	valid_0's binary_logloss: 0.00383516
# [143]	valid_0's binary_logloss: 0.00385466
# [144]	valid_0's binary_logloss: 0.00387056
# [145]	valid_0's binary_logloss: 0.00389
# [146]	valid_0's binary_logloss: 0.00390993
# [147]	valid_0's binary_logloss: 0.00393117
# [148]	valid_0's binary_logloss: 0.00394741
# [149]	valid_0's binary_logloss: 0.00396318
# [150]	valid_0's binary_logloss: 0.00396836
# [151]	valid_0's binary_logloss: 0.00398217
# [152]	valid_0's binary_logloss: 0.00400668
# [153]	valid_0's binary_logloss: 0.00401843
# [154]	valid_0's binary_logloss: 0.00404971
# [155]	valid_0's binary_logloss: 0.00407539
# [156]	valid_0's binary_logloss: 0.00409369
# [157]	valid_0's binary_logloss: 0.00411676
# [158]	valid_0's binary_logloss: 0.00413536
# [159]	valid_0's binary_logloss: 0.00415209
# [160]	valid_0's binary_logloss: 0.00416868
# [161]	valid_0's binary_logloss: 0.00418178
# [162]	valid_0's binary_logloss: 0.00419989
# [163]	valid_0's binary_logloss: 0.00420965
# [164]	valid_0's binary_logloss: 0.00422915
# [165]	valid_0's binary_logloss: 0.0042476
# [166]	valid_0's binary_logloss: 0.00426634
# [167]	valid_0's binary_logloss: 0.00428456

# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [233]	valid_0's binary_logloss: 0.00533994
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [234]	valid_0's binary_logloss: 0.00534944
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [235]	valid_0's binary_logloss: 0.00535229
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [236]	valid_0's binary_logloss: 0.00536321
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [237]	valid_0's binary_logloss: 0.00537045
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [238]	valid_0's binary_logloss: 0.00538049
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [239]	valid_0's binary_logloss: 0.00539747
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [240]	valid_0's binary_logloss: 0.00540408
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [241]	valid_0's binary_logloss: 0.00541205
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [242]	valid_0's binary_logloss: 0.00542258
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [243]	valid_0's binary_logloss: 0.00543731
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [244]	valid_0's binary_logloss: 0.0054454
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [245]	valid_0's binary_logloss: 0.00546185
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [246]	valid_0's binary_logloss: 0.00546798
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [247]	valid_0's binary_logloss: 0.00547718
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [248]	valid_0's binary_logloss: 0.00548688
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [249]	valid_0's binary_logloss: 0.00549347
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [250]	valid_0's binary_logloss: 0.00550561
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [251]	valid_0's binary_logloss: 0.00551197
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [252]	valid_0's binary_logloss: 0.00552321
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [253]	valid_0's binary_logloss: 0.00552532
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [254]	valid_0's binary_logloss: 0.00552914
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [255]	valid_0's binary_logloss: 0.00553486
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [256]	valid_0's binary_logloss: 0.00554329
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [257]	valid_0's binary_logloss: 0.00555135
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [258]	valid_0's binary_logloss: 0.0055567
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [259]	valid_0's binary_logloss: 0.00556021
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [260]	valid_0's binary_logloss: 0.00556513
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [261]	valid_0's binary_logloss: 0.00557261
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [262]	valid_0's binary_logloss: 0.00557844
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [263]	valid_0's binary_logloss: 0.00558605
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [264]	valid_0's binary_logloss: 0.00559009
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [265]	valid_0's binary_logloss: 0.00559391
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [266]	valid_0's binary_logloss: 0.00560098
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [267]	valid_0's binary_logloss: 0.00560304
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [268]	valid_0's binary_logloss: 0.00561446
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [269]	valid_0's binary_logloss: 0.00562039
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [270]	valid_0's binary_logloss: 0.00562405
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [271]	valid_0's binary_logloss: 0.00562604
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [272]	valid_0's binary_logloss: 0.00563154
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [273]	valid_0's binary_logloss: 0.00563174
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [274]	valid_0's binary_logloss: 0.00563276
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [275]	valid_0's binary_logloss: 0.00564104
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [276]	valid_0's binary_logloss: 0.00564336
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [277]	valid_0's binary_logloss: 0.00565005
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [278]	valid_0's binary_logloss: 0.0056536
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [279]	valid_0's binary_logloss: 0.00565978
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [280]	valid_0's binary_logloss: 0.00566138
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [281]	valid_0's binary_logloss: 0.00566344
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [282]	valid_0's binary_logloss: 0.00566523
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [283]	valid_0's binary_logloss: 0.00566935
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [284]	valid_0's binary_logloss: 0.00567345
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [285]	valid_0's binary_logloss: 0.00568042
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [286]	valid_0's binary_logloss: 0.00568406
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [287]	valid_0's binary_logloss: 0.00568813
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [288]	valid_0's binary_logloss: 0.005693
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [289]	valid_0's binary_logloss: 0.00569697
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [290]	valid_0's binary_logloss: 0.00569645
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [291]	valid_0's binary_logloss: 0.00569766
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [292]	valid_0's binary_logloss: 0.00570288
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [293]	valid_0's binary_logloss: 0.0057086
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [294]	valid_0's binary_logloss: 0.00571121
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [295]	valid_0's binary_logloss: 0.0057163
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [296]	valid_0's binary_logloss: 0.00572203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [297]	valid_0's binary_logloss: 0.00571958
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [298]	valid_0's binary_logloss: 0.00572026
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [299]	valid_0's binary_logloss: 0.0057265
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [300]	valid_0's binary_logloss: 0.0057283
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [301]	valid_0's binary_logloss: 0.00573128
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [302]	valid_0's binary_logloss: 0.00573406
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [303]	valid_0's binary_logloss: 0.0057391
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [304]	valid_0's binary_logloss: 0.00573999
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [305]	valid_0's binary_logloss: 0.00574153
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [306]	valid_0's binary_logloss: 0.00574525
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [307]	valid_0's binary_logloss: 0.00574703
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [308]	valid_0's binary_logloss: 0.00574914
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [309]	valid_0's binary_logloss: 0.00574925
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [310]	valid_0's binary_logloss: 0.00574844
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [311]	valid_0's binary_logloss: 0.00575128
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [312]	valid_0's binary_logloss: 0.00575129
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [313]	valid_0's binary_logloss: 0.0057522
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [314]	valid_0's binary_logloss: 0.00575683
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [315]	valid_0's binary_logloss: 0.00576132
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [316]	valid_0's binary_logloss: 0.00576317
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [317]	valid_0's binary_logloss: 0.0057657
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [318]	valid_0's binary_logloss: 0.00576871
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [319]	valid_0's binary_logloss: 0.00576874
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [320]	valid_0's binary_logloss: 0.00577323
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [321]	valid_0's binary_logloss: 0.00577557
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [322]	valid_0's binary_logloss: 0.00578135
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [323]	valid_0's binary_logloss: 0.00578081
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [324]	valid_0's binary_logloss: 0.00578377
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [325]	valid_0's binary_logloss: 0.00578554
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [326]	valid_0's binary_logloss: 0.00578651
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [327]	valid_0's binary_logloss: 0.00578757
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [328]	valid_0's binary_logloss: 0.00578693
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [329]	valid_0's binary_logloss: 0.00578913
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [330]	valid_0's binary_logloss: 0.00579255
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [331]	valid_0's binary_logloss: 0.00579383
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [332]	valid_0's binary_logloss: 0.00579376
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [333]	valid_0's binary_logloss: 0.00579342
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [334]	valid_0's binary_logloss: 0.0057983
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [335]	valid_0's binary_logloss: 0.00579833
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [336]	valid_0's binary_logloss: 0.0058008
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [337]	valid_0's binary_logloss: 0.00580509
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [338]	valid_0's binary_logloss: 0.00581038
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [339]	valid_0's binary_logloss: 0.0058151
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [340]	valid_0's binary_logloss: 0.00581588
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [341]	valid_0's binary_logloss: 0.00581895
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [342]	valid_0's binary_logloss: 0.00582007
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [343]	valid_0's binary_logloss: 0.00582053
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [344]	valid_0's binary_logloss: 0.00582308
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [345]	valid_0's binary_logloss: 0.00582598
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [346]	valid_0's binary_logloss: 0.00582711
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [347]	valid_0's binary_logloss: 0.00582626
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [348]	valid_0's binary_logloss: 0.00582835
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [349]	valid_0's binary_logloss: 0.0058293
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [350]	valid_0's binary_logloss: 0.00582833
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [351]	valid_0's binary_logloss: 0.00583086
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [352]	valid_0's binary_logloss: 0.00583483
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [353]	valid_0's binary_logloss: 0.00583762
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [354]	valid_0's binary_logloss: 0.00584029
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [355]	valid_0's binary_logloss: 0.00584316
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [356]	valid_0's binary_logloss: 0.00584399
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [357]	valid_0's binary_logloss: 0.00584059
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [358]	valid_0's binary_logloss: 0.00584175
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [359]	valid_0's binary_logloss: 0.00584325
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [360]	valid_0's binary_logloss: 0.00584497
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [361]	valid_0's binary_logloss: 0.00584702
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [362]	valid_0's binary_logloss: 0.00584809
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [363]	valid_0's binary_logloss: 0.00584646
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [364]	valid_0's binary_logloss: 0.00585129
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [365]	valid_0's binary_logloss: 0.00585439
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [366]	valid_0's binary_logloss: 0.00585454
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [367]	valid_0's binary_logloss: 0.00585608
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [368]	valid_0's binary_logloss: 0.0058584
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [369]	valid_0's binary_logloss: 0.00585623
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [370]	valid_0's binary_logloss: 0.00585766
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [371]	valid_0's binary_logloss: 0.0058601
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [372]	valid_0's binary_logloss: 0.00586299
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [373]	valid_0's binary_logloss: 0.00586659
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [374]	valid_0's binary_logloss: 0.00586689
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [375]	valid_0's binary_logloss: 0.00586862
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [376]	valid_0's binary_logloss: 0.00586716
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [377]	valid_0's binary_logloss: 0.00587196
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [378]	valid_0's binary_logloss: 0.00587363
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [379]	valid_0's binary_logloss: 0.00587132
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [380]	valid_0's binary_logloss: 0.00587259
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [381]	valid_0's binary_logloss: 0.00587695
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [382]	valid_0's binary_logloss: 0.00587551
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [383]	valid_0's binary_logloss: 0.00587712
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [384]	valid_0's binary_logloss: 0.00587856
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [385]	valid_0's binary_logloss: 0.00587707
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [386]	valid_0's binary_logloss: 0.00587937
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [387]	valid_0's binary_logloss: 0.00588183
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [388]	valid_0's binary_logloss: 0.00588422
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [389]	valid_0's binary_logloss: 0.00588401
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [390]	valid_0's binary_logloss: 0.00588426
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [391]	valid_0's binary_logloss: 0.00588503
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [392]	valid_0's binary_logloss: 0.00588759
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [393]	valid_0's binary_logloss: 0.00589174
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [394]	valid_0's binary_logloss: 0.00589193
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [395]	valid_0's binary_logloss: 0.00589302
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [396]	valid_0's binary_logloss: 0.00589556
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [397]	valid_0's binary_logloss: 0.005894
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [398]	valid_0's binary_logloss: 0.005896
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [399]	valid_0's binary_logloss: 0.00589867
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [400]	valid_0's binary_logloss: 0.00590071
# LGBMClassifier(boost_from_average=False, force_col_wise=True, n_estimators=400)
# 오차행렬 :  [[85291     4]
#  [   37   111]]
# 정확도: 0.9995, 정밀도: 0.9652,  재현율: 0.7500, F1 Score: 0.8441, ROC_AUC : 0.9805

# %%
# (2) 로그변환 (X) / 이상치 제거 (X) / 오버샘플링 (O) / early_stopping(100) (X) 

from lightgbm import LGBMClassifier, early_stopping, log_evaluation
from imblearn.over_sampling import SMOTE

df_copy = card_df.copy()

X_train, X_test, y_train, y_test = get_train_test_dataset(df_copy)

# 오버 샘플링



print('LightGBM 예측 성능')



# 오차행렬 :  [[85285    10]
#  [   32   116]]
# 정확도: 0.9995, 정밀도: 0.9206,  재현율: 0.7838, F1 Score: 0.8467, ROC_AUC : 0.9552
# Out:
# LightGBM 예측 성능
# [LightGBM] [Info] Number of positive: 199020, number of negative: 199020
# [LightGBM] [Info] Total Bins 7395
# [LightGBM] [Info] Number of data points in the train set: 398040, number of used features: 29
# [1]	valid_0's binary_logloss: 0.606299
# [2]	valid_0's binary_logloss: 0.534626
# [3]	valid_0's binary_logloss: 0.474603
# [198]	valid_0's binary_logloss: 0.00478566
# [199]	valid_0's binary_logloss: 0.0047847
# [200]	valid_0's binary_logloss: 0.00478886
# [201]	valid_0's binary_logloss: 0.00479349
# [202]	valid_0's binary_logloss: 0.00479265
# [203]	valid_0's binary_logloss: 0.00480006
# [204]	valid_0's binary_logloss: 0.00480452
# [205]	valid_0's binary_logloss: 0.00480532
# [206]	valid_0's binary_logloss: 0.00480966
# [207]	valid_0's binary_logloss: 0.00481289
# [208]	valid_0's binary_logloss: 0.00481946
# [209]	valid_0's binary_logloss: 0.00481885
# [210]	valid_0's binary_logloss: 0.00482463
# [211]	valid_0's binary_logloss: 0.004831
# [212]	valid_0's binary_logloss: 0.004838
# [213]	valid_0's binary_logloss: 0.0048403
# [214]	valid_0's binary_logloss: 0.00485404
# [215]	valid_0's binary_logloss: 0.00486191
# [216]	valid_0's binary_logloss: 0.00486851
# [217]	valid_0's binary_logloss: 0.00487225
# [218]	valid_0's binary_logloss: 0.00487991
# [219]	valid_0's binary_logloss: 0.00488106
# [220]	valid_0's binary_logloss: 0.00488129
# [221]	valid_0's binary_logloss: 0.00488539
# [222]	valid_0's binary_logloss: 0.00488584
# [223]	valid_0's binary_logloss: 0.00489172
# [224]	valid_0's binary_logloss: 0.00490029
# [225]	valid_0's binary_logloss: 0.00490293
# [226]	valid_0's binary_logloss: 0.00490642
# [227]	valid_0's binary_logloss: 0.00490558
# [228]	valid_0's binary_logloss: 0.00490854
# [229]	valid_0's binary_logloss: 0.00491277
# [230]	valid_0's binary_logloss: 0.00492363
# [231]	valid_0's binary_logloss: 0.00492779
# [232]	valid_0's binary_logloss: 0.00493448
# [233]	valid_0's binary_logloss: 0.00493739
# [234]	valid_0's binary_logloss: 0.00493966
# [235]	valid_0's binary_logloss: 0.00494282
# [236]	valid_0's binary_logloss: 0.00494998
# [237]	valid_0's binary_logloss: 0.0049556
# [238]	valid_0's binary_logloss: 0.00495617
# [239]	valid_0's binary_logloss: 0.0049629
# [240]	valid_0's binary_logloss: 0.00497362
# [241]	valid_0's binary_logloss: 0.00498136
# [242]	valid_0's binary_logloss: 0.00498687
# [243]	valid_0's binary_logloss: 0.00498698
# [244]	valid_0's binary_logloss: 0.00498764
# [245]	valid_0's binary_logloss: 0.00499885
# [246]	valid_0's binary_logloss: 0.00500759
# [247]	valid_0's binary_logloss: 0.00501414
# [248]	valid_0's binary_logloss: 0.00502231
# [249]	valid_0's binary_logloss: 0.00502766
# [250]	valid_0's binary_logloss: 0.00503833
# [251]	valid_0's binary_logloss: 0.00504554
# [252]	valid_0's binary_logloss: 0.00505443
# [253]	valid_0's binary_logloss: 0.00505946
# [254]	valid_0's binary_logloss: 0.00506762
# [255]	valid_0's binary_logloss: 0.00507763
# [256]	valid_0's binary_logloss: 0.00507932
# [257]	valid_0's binary_logloss: 0.00509059
# [258]	valid_0's binary_logloss: 0.00509946
# [259]	valid_0's binary_logloss: 0.00511152
# [260]	valid_0's binary_logloss: 0.00511601
# [261]	valid_0's binary_logloss: 0.00512451
# [262]	valid_0's binary_logloss: 0.00512987
# [263]	valid_0's binary_logloss: 0.00513796
# [264]	valid_0's binary_logloss: 0.00514635
# [265]	valid_0's binary_logloss: 0.00515102
# [266]	valid_0's binary_logloss: 0.0051592
# [267]	valid_0's binary_logloss: 0.00517027
# [268]	valid_0's binary_logloss: 0.00517611
# [269]	valid_0's binary_logloss: 0.00518507
# [270]	valid_0's binary_logloss: 0.00519018
# [271]	valid_0's binary_logloss: 0.0051967
# [272]	valid_0's binary_logloss: 0.0052059
# [273]	valid_0's binary_logloss: 0.00521008
# [274]	valid_0's binary_logloss: 0.00521239
# [275]	valid_0's binary_logloss: 0.00521717
# [276]	valid_0's binary_logloss: 0.00522705
# [277]	valid_0's binary_logloss: 0.00523831
# [278]	valid_0's binary_logloss: 0.00524845
# [279]	valid_0's binary_logloss: 0.00525912
# [280]	valid_0's binary_logloss: 0.00526914
# [281]	valid_0's binary_logloss: 0.00526972
# [282]	valid_0's binary_logloss: 0.00528058
# [283]	valid_0's binary_logloss: 0.00528714
# [284]	valid_0's binary_logloss: 0.00529789
# [285]	valid_0's binary_logloss: 0.00530746
# [286]	valid_0's binary_logloss: 0.00531489
# [287]	valid_0's binary_logloss: 0.00532105
# [288]	valid_0's binary_logloss: 0.00532942
# [289]	valid_0's binary_logloss: 0.00533401
# [290]	valid_0's binary_logloss: 0.005339
# [291]	valid_0's binary_logloss: 0.00534866
# [292]	valid_0's binary_logloss: 0.00535774
# [293]	valid_0's binary_logloss: 0.0053589
# [294]	valid_0's binary_logloss: 0.0053767
# [295]	valid_0's binary_logloss: 0.0053838
# [296]	valid_0's binary_logloss: 0.00538517
# [297]	valid_0's binary_logloss: 0.00539269
# [298]	valid_0's binary_logloss: 0.0054045
# [299]	valid_0's binary_logloss: 0.00541259
# [300]	valid_0's binary_logloss: 0.00541985
# [301]	valid_0's binary_logloss: 0.00543346
# [302]	valid_0's binary_logloss: 0.00543972
# [303]	valid_0's binary_logloss: 0.00545056
# [304]	valid_0's binary_logloss: 0.0054592
# [305]	valid_0's binary_logloss: 0.00546476
# [306]	valid_0's binary_logloss: 0.00548205
# [307]	valid_0's binary_logloss: 0.00549243
# [308]	valid_0's binary_logloss: 0.00549867
# [309]	valid_0's binary_logloss: 0.00550251
# [310]	valid_0's binary_logloss: 0.0055122
# [311]	valid_0's binary_logloss: 0.00552014
# [312]	valid_0's binary_logloss: 0.00552771
# [313]	valid_0's binary_logloss: 0.00554509
# [314]	valid_0's binary_logloss: 0.00555101
# [315]	valid_0's binary_logloss: 0.00555973
# [316]	valid_0's binary_logloss: 0.00556632
# [317]	valid_0's binary_logloss: 0.00557092
# [318]	valid_0's binary_logloss: 0.00558106
# [319]	valid_0's binary_logloss: 0.00558709
# [320]	valid_0's binary_logloss: 0.00559659
# [321]	valid_0's binary_logloss: 0.00559805
# [322]	valid_0's binary_logloss: 0.00561175
# [323]	valid_0's binary_logloss: 0.00561519
# [324]	valid_0's binary_logloss: 0.00562112
# [325]	valid_0's binary_logloss: 0.00562937
# [326]	valid_0's binary_logloss: 0.00562792
# [327]	valid_0's binary_logloss: 0.005642
# [328]	valid_0's binary_logloss: 0.00564996
# [329]	valid_0's binary_logloss: 0.00566208
# [330]	valid_0's binary_logloss: 0.00566549
# [331]	valid_0's binary_logloss: 0.0056834
# [332]	valid_0's binary_logloss: 0.00569019
# [333]	valid_0's binary_logloss: 0.00569763
# [334]	valid_0's binary_logloss: 0.00570652
# [335]	valid_0's binary_logloss: 0.00571897
# [336]	valid_0's binary_logloss: 0.00572283
# [337]	valid_0's binary_logloss: 0.00573101
# [338]	valid_0's binary_logloss: 0.00573776
# [339]	valid_0's binary_logloss: 0.00574339
# [340]	valid_0's binary_logloss: 0.00574849
# [341]	valid_0's binary_logloss: 0.0057592
# [342]	valid_0's binary_logloss: 0.00576595
# [343]	valid_0's binary_logloss: 0.00577147
# [344]	valid_0's binary_logloss: 0.00577332
# [345]	valid_0's binary_logloss: 0.00577895
# [346]	valid_0's binary_logloss: 0.005791
# [347]	valid_0's binary_logloss: 0.00579676
# [348]	valid_0's binary_logloss: 0.0058051
# [349]	valid_0's binary_logloss: 0.00580965
# [350]	valid_0's binary_logloss: 0.00582208
# [351]	valid_0's binary_logloss: 0.00582545
# [352]	valid_0's binary_logloss: 0.00583737
# [353]	valid_0's binary_logloss: 0.00584607
# [354]	valid_0's binary_logloss: 0.00585133
# [355]	valid_0's binary_logloss: 0.00586416
# [356]	valid_0's binary_logloss: 0.00587301
# [357]	valid_0's binary_logloss: 0.00587916
# [358]	valid_0's binary_logloss: 0.00589036
# [359]	valid_0's binary_logloss: 0.00589864
# [360]	valid_0's binary_logloss: 0.00590791
# [361]	valid_0's binary_logloss: 0.00591603
# [362]	valid_0's binary_logloss: 0.00593119
# [363]	valid_0's binary_logloss: 0.00594212
# [364]	valid_0's binary_logloss: 0.00594341
# [365]	valid_0's binary_logloss: 0.00595218
# [366]	valid_0's binary_logloss: 0.00596108
# [367]	valid_0's binary_logloss: 0.00596372
# [368]	valid_0's binary_logloss: 0.00596898
# [369]	valid_0's binary_logloss: 0.00597986
# [370]	valid_0's binary_logloss: 0.00598872
# [371]	valid_0's binary_logloss: 0.00599523
# [372]	valid_0's binary_logloss: 0.00600682
# [373]	valid_0's binary_logloss: 0.00601003
# [374]	valid_0's binary_logloss: 0.00602177
# [375]	valid_0's binary_logloss: 0.00602694
# [376]	valid_0's binary_logloss: 0.00603442
# [377]	valid_0's binary_logloss: 0.00604747
# [378]	valid_0's binary_logloss: 0.00605838
# [379]	valid_0's binary_logloss: 0.00606447
# [380]	valid_0's binary_logloss: 0.00606835
# [381]	valid_0's binary_logloss: 0.00607961
# [382]	valid_0's binary_logloss: 0.00608786
# [383]	valid_0's binary_logloss: 0.00609926
# [384]	valid_0's binary_logloss: 0.00610792
# [385]	valid_0's binary_logloss: 0.00611545
# [386]	valid_0's binary_logloss: 0.00612417
# [387]	valid_0's binary_logloss: 0.00612885
# [388]	valid_0's binary_logloss: 0.00613743
# [389]	valid_0's binary_logloss: 0.0061469
# [390]	valid_0's binary_logloss: 0.00615857
# [391]	valid_0's binary_logloss: 0.00616266
# [392]	valid_0's binary_logloss: 0.00617042
# [393]	valid_0's binary_logloss: 0.00617648
# [394]	valid_0's binary_logloss: 0.00618238
# [395]	valid_0's binary_logloss: 0.0061925
# [396]	valid_0's binary_logloss: 0.00620304
# [397]	valid_0's binary_logloss: 0.00620902
# [398]	valid_0's binary_logloss: 0.0062117
# [399]	valid_0's binary_logloss: 0.00622549
# [400]	valid_0's binary_logloss: 0.00623103
# LGBMClassifier(boost_from_average=False, force_col_wise=True, n_estimators=400)
# 오차행렬 :  [[85285    10]
#  [   32   116]]
# 정확도: 0.9995, 정밀도: 0.9206,  재현율: 0.7838, F1 Score: 0.8467, ROC_AUC : 0.9552

# %%
# (3) 로그변환 (X) / 이상치 제거 (X) / 오버샘플링 (O) / early_stopping(100) (O) 

from lightgbm import LGBMClassifier, early_stopping, log_evaluation
from imblearn.over_sampling import SMOTE

df_copy = card_df.copy()

X_train, X_test, y_train, y_test = get_train_test_dataset(df_copy)

# 오버 샘플링
smote = SMOTE(random_state=0)
# 학습용 데이터 세트에만 오버샘플링 적용
X_train_over, y_train_over = smote.fit_resample(X_train, y_train)


print('LightGBM 예측 성능')



# 오차행렬 :  [[85233    62]
#  [   23   125]]
# 정확도: 0.9990, 정밀도: 0.6684,  재현율: 0.8446, F1 Score: 0.7463, ROC_AUC : 0.9779
# Out:
# LightGBM 예측 성능
# [LightGBM] [Info] Number of positive: 199020, number of negative: 199020
# [LightGBM] [Info] Total Bins 7395
# [LightGBM] [Info] Number of data points in the train set: 398040, number of used features: 29
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [102]	valid_0's binary_logloss: 0.00444271
# LGBMClassifier(boost_from_average=False, force_col_wise=True, n_estimators=400)
# 오차행렬 :  [[85233    62]
#  [   23   125]]
# 정확도: 0.9990, 정밀도: 0.6684,  재현율: 0.8446, F1 Score: 0.7463, ROC_AUC : 0.9779

# %%
# (4) 로그변환 (O) / 이상치 제거 (O) / 오버샘플링 (X) / early_stopping(100) (X) 

from lightgbm import LGBMClassifier, early_stopping, log_evaluation

df_copy = card_df.copy()

# 로그변환 

# 이상치 데이터 삭제


X_train, X_test, y_train, y_test = get_train_test_dataset(df_copy)

print('LightGBM 예측 성능')
# Out:
# LightGBM 예측 성능
# [LightGBM] [Info] Number of positive: 339, number of negative: 199020
# [LightGBM] [Info] Total Bins 7650
# [LightGBM] [Info] Number of data points in the train set: 199359, number of used features: 30
# [1]	valid_0's binary_logloss: 0.598322
# [2]	valid_0's binary_logloss: 0.520668
# [3]	valid_0's binary_logloss: 0.455905
# [4]	valid_0's binary_logloss: 0.401169
# [5]	valid_0's binary_logloss: 0.35441
# [6]	valid_0's binary_logloss: 0.314132
# [7]	valid_0's binary_logloss: 0.279208
# [8]	valid_0's binary_logloss: 0.248739
# [9]	valid_0's binary_logloss: 0.222042
# [10]	valid_0's binary_logloss: 0.198567
# [11]	valid_0's binary_logloss: 0.177842
# [12]	valid_0's binary_logloss: 0.159496
# [13]	valid_0's binary_logloss: 0.143227
# [14]	valid_0's binary_logloss: 0.128751
# [15]	valid_0's binary_logloss: 0.11585
# [81]	valid_0's binary_logloss: 0.003167
# [82]	valid_0's binary_logloss: 0.0031613
# [83]	valid_0's binary_logloss: 0.0031492
# [84]	valid_0's binary_logloss: 0.00314552
# [85]	valid_0's binary_logloss: 0.00314656
# [86]	valid_0's binary_logloss: 0.00314702
# [87]	valid_0's binary_logloss: 0.00315163
# [88]	valid_0's binary_logloss: 0.00315122
# [89]	valid_0's binary_logloss: 0.00315688
# [90]	valid_0's binary_logloss: 0.00315853
# [91]	valid_0's binary_logloss: 0.00315975
# [92]	valid_0's binary_logloss: 0.0031702
# [93]	valid_0's binary_logloss: 0.00318068
# [94]	valid_0's binary_logloss: 0.00318577
# [95]	valid_0's binary_logloss: 0.00318722
# [96]	valid_0's binary_logloss: 0.00319865
# [97]	valid_0's binary_logloss: 0.00320025
# [98]	valid_0's binary_logloss: 0.00320165
# [99]	valid_0's binary_logloss: 0.00320518
# [100]	valid_0's binary_logloss: 0.00321762
# [101]	valid_0's binary_logloss: 0.00322464
# [102]	valid_0's binary_logloss: 0.00324415
# [103]	valid_0's binary_logloss: 0.00325218
# [104]	valid_0's binary_logloss: 0.00326796
# [105]	valid_0's binary_logloss: 0.00327882
# [106]	valid_0's binary_logloss: 0.00328424
# [107]	valid_0's binary_logloss: 0.00329796
# [108]	valid_0's binary_logloss: 0.003308
# [109]	valid_0's binary_logloss: 0.00331455
# [110]	valid_0's binary_logloss: 0.00331984
# [111]	valid_0's binary_logloss: 0.00332866
# [112]	valid_0's binary_logloss: 0.0033432
# [113]	valid_0's binary_logloss: 0.00335398
# [114]	valid_0's binary_logloss: 0.00336803
# [115]	valid_0's binary_logloss: 0.00337723
# [116]	valid_0's binary_logloss: 0.00338345
# [117]	valid_0's binary_logloss: 0.00339625
# [118]	valid_0's binary_logloss: 0.00340214
# [119]	valid_0's binary_logloss: 0.00341525
# [120]	valid_0's binary_logloss: 0.00343479
# [121]	valid_0's binary_logloss: 0.00344799
# [122]	valid_0's binary_logloss: 0.00345584
# [123]	valid_0's binary_logloss: 0.00347192
# [124]	valid_0's binary_logloss: 0.00348804
# [125]	valid_0's binary_logloss: 0.00349986
# [126]	valid_0's binary_logloss: 0.00351211
# [127]	valid_0's binary_logloss: 0.00352979
# [128]	valid_0's binary_logloss: 0.00354365
# [129]	valid_0's binary_logloss: 0.00355906
# [130]	valid_0's binary_logloss: 0.00356852
# [131]	valid_0's binary_logloss: 0.00358551
# [132]	valid_0's binary_logloss: 0.00360064
# [133]	valid_0's binary_logloss: 0.00361661
# [134]	valid_0's binary_logloss: 0.00362243
# [135]	valid_0's binary_logloss: 0.00363468
# [136]	valid_0's binary_logloss: 0.00364627
# [137]	valid_0's binary_logloss: 0.00366276
# [138]	valid_0's binary_logloss: 0.00367472
# [139]	valid_0's binary_logloss: 0.00369014
# [140]	valid_0's binary_logloss: 0.0037021
# [141]	valid_0's binary_logloss: 0.00372141
# [142]	valid_0's binary_logloss: 0.00372501
# [143]	valid_0's binary_logloss: 0.00373885
# [144]	valid_0's binary_logloss: 0.00375237
# [210]	valid_0's binary_logloss: 0.00462373
# [211]	valid_0's binary_logloss: 0.00463969
# [212]	valid_0's binary_logloss: 0.00465247
# [213]	valid_0's binary_logloss: 0.00466606
# [214]	valid_0's binary_logloss: 0.00468129
# [215]	valid_0's binary_logloss: 0.00468943
# [216]	valid_0's binary_logloss: 0.00470289
# [217]	valid_0's binary_logloss: 0.00472035
# [218]	valid_0's binary_logloss: 0.00473436
# [219]	valid_0's binary_logloss: 0.00474837
# [220]	valid_0's binary_logloss: 0.0047621
# [221]	valid_0's binary_logloss: 0.00477424
# [222]	valid_0's binary_logloss: 0.0048006
# [223]	valid_0's binary_logloss: 0.0048176
# [224]	valid_0's binary_logloss: 0.00483184
# [225]	valid_0's binary_logloss: 0.0048511
# [226]	valid_0's binary_logloss: 0.004864
# [227]	valid_0's binary_logloss: 0.00487984
# [228]	valid_0's binary_logloss: 0.00489076
# [229]	valid_0's binary_logloss: 0.00490649
# [230]	valid_0's binary_logloss: 0.00491533
# [231]	valid_0's binary_logloss: 0.00492824
# [232]	valid_0's binary_logloss: 0.0049389
# [233]	valid_0's binary_logloss: 0.00495141
# [234]	valid_0's binary_logloss: 0.00496121
# [235]	valid_0's binary_logloss: 0.00497257
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [236]	valid_0's binary_logloss: 0.0049762
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [237]	valid_0's binary_logloss: 0.00498669
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [238]	valid_0's binary_logloss: 0.00500189
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [239]	valid_0's binary_logloss: 0.00500973
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [240]	valid_0's binary_logloss: 0.00501801
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [241]	valid_0's binary_logloss: 0.00502304
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [242]	valid_0's binary_logloss: 0.00503092
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [243]	valid_0's binary_logloss: 0.00504035
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [244]	valid_0's binary_logloss: 0.00505132
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [245]	valid_0's binary_logloss: 0.00505725
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [246]	valid_0's binary_logloss: 0.00506605
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [247]	valid_0's binary_logloss: 0.00507321
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [248]	valid_0's binary_logloss: 0.00508542
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [249]	valid_0's binary_logloss: 0.0050938
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [250]	valid_0's binary_logloss: 0.00509929
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [251]	valid_0's binary_logloss: 0.00510701
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [252]	valid_0's binary_logloss: 0.0051181
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [253]	valid_0's binary_logloss: 0.00512048
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [254]	valid_0's binary_logloss: 0.00512889
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [255]	valid_0's binary_logloss: 0.00513595
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [256]	valid_0's binary_logloss: 0.00514014
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [257]	valid_0's binary_logloss: 0.0051506
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [258]	valid_0's binary_logloss: 0.00515575
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [259]	valid_0's binary_logloss: 0.00516344
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [260]	valid_0's binary_logloss: 0.00517314
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [261]	valid_0's binary_logloss: 0.00518223
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [262]	valid_0's binary_logloss: 0.00518529
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [263]	valid_0's binary_logloss: 0.00519017
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [264]	valid_0's binary_logloss: 0.00519741
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [265]	valid_0's binary_logloss: 0.00520308
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [266]	valid_0's binary_logloss: 0.00521138
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [267]	valid_0's binary_logloss: 0.00521419
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [268]	valid_0's binary_logloss: 0.00521913
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [269]	valid_0's binary_logloss: 0.00522041
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [270]	valid_0's binary_logloss: 0.00522724
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [271]	valid_0's binary_logloss: 0.00523292
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [272]	valid_0's binary_logloss: 0.00524354
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [273]	valid_0's binary_logloss: 0.00524767
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [274]	valid_0's binary_logloss: 0.00524466
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [275]	valid_0's binary_logloss: 0.0052544
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [276]	valid_0's binary_logloss: 0.00525444
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [277]	valid_0's binary_logloss: 0.00526199
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [278]	valid_0's binary_logloss: 0.00526698
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [279]	valid_0's binary_logloss: 0.00526827
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [280]	valid_0's binary_logloss: 0.00527552
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [281]	valid_0's binary_logloss: 0.00528103
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [282]	valid_0's binary_logloss: 0.0052842
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [283]	valid_0's binary_logloss: 0.00529225
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [284]	valid_0's binary_logloss: 0.00529391
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [285]	valid_0's binary_logloss: 0.00529843
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [286]	valid_0's binary_logloss: 0.00530176
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [287]	valid_0's binary_logloss: 0.00530735
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [288]	valid_0's binary_logloss: 0.00531141
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [289]	valid_0's binary_logloss: 0.00531517
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [290]	valid_0's binary_logloss: 0.00531617
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [291]	valid_0's binary_logloss: 0.00531582
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [292]	valid_0's binary_logloss: 0.00531905
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [293]	valid_0's binary_logloss: 0.00532364
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [294]	valid_0's binary_logloss: 0.0053285
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [295]	valid_0's binary_logloss: 0.00533018
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [296]	valid_0's binary_logloss: 0.00533581
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [297]	valid_0's binary_logloss: 0.00533291
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [298]	valid_0's binary_logloss: 0.00533598
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [299]	valid_0's binary_logloss: 0.00533756
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [300]	valid_0's binary_logloss: 0.00534507
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [301]	valid_0's binary_logloss: 0.00534472
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [302]	valid_0's binary_logloss: 0.00535023
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [303]	valid_0's binary_logloss: 0.00535033
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [304]	valid_0's binary_logloss: 0.00534937
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [305]	valid_0's binary_logloss: 0.0053535
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [306]	valid_0's binary_logloss: 0.00535563
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [307]	valid_0's binary_logloss: 0.00535663
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [308]	valid_0's binary_logloss: 0.00535858
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [309]	valid_0's binary_logloss: 0.00536273
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [310]	valid_0's binary_logloss: 0.005367
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [311]	valid_0's binary_logloss: 0.00537257
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [312]	valid_0's binary_logloss: 0.00537546
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [313]	valid_0's binary_logloss: 0.00537517
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [314]	valid_0's binary_logloss: 0.005375
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [315]	valid_0's binary_logloss: 0.00537521
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [316]	valid_0's binary_logloss: 0.00537663
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [317]	valid_0's binary_logloss: 0.00537767
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [318]	valid_0's binary_logloss: 0.00537922
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [319]	valid_0's binary_logloss: 0.00538335
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [320]	valid_0's binary_logloss: 0.00538667
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [321]	valid_0's binary_logloss: 0.00538463
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [322]	valid_0's binary_logloss: 0.00538743
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [323]	valid_0's binary_logloss: 0.00538612
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [324]	valid_0's binary_logloss: 0.00539043
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [325]	valid_0's binary_logloss: 0.00539148
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [326]	valid_0's binary_logloss: 0.00539225
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [327]	valid_0's binary_logloss: 0.00539406
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [328]	valid_0's binary_logloss: 0.00539751
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [329]	valid_0's binary_logloss: 0.00539799
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [330]	valid_0's binary_logloss: 0.00539775
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [331]	valid_0's binary_logloss: 0.00540015
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [332]	valid_0's binary_logloss: 0.00540203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [333]	valid_0's binary_logloss: 0.00540322
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [334]	valid_0's binary_logloss: 0.00540555
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [335]	valid_0's binary_logloss: 0.00540749
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [336]	valid_0's binary_logloss: 0.00540829
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [337]	valid_0's binary_logloss: 0.00541126
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [338]	valid_0's binary_logloss: 0.00541402
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [339]	valid_0's binary_logloss: 0.00541474
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [340]	valid_0's binary_logloss: 0.00541631
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [341]	valid_0's binary_logloss: 0.00541999
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [342]	valid_0's binary_logloss: 0.00542069
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [343]	valid_0's binary_logloss: 0.00542453
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [344]	valid_0's binary_logloss: 0.00542495
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [345]	valid_0's binary_logloss: 0.00542694
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [346]	valid_0's binary_logloss: 0.0054268
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [347]	valid_0's binary_logloss: 0.00542758
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [348]	valid_0's binary_logloss: 0.00543029
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [349]	valid_0's binary_logloss: 0.00543402
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [350]	valid_0's binary_logloss: 0.0054351
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [351]	valid_0's binary_logloss: 0.00543444
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [352]	valid_0's binary_logloss: 0.00543732
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [353]	valid_0's binary_logloss: 0.00543954
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [354]	valid_0's binary_logloss: 0.00543719
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [355]	valid_0's binary_logloss: 0.00544013
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [356]	valid_0's binary_logloss: 0.0054389
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [357]	valid_0's binary_logloss: 0.00543871
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [358]	valid_0's binary_logloss: 0.0054414
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [359]	valid_0's binary_logloss: 0.00544143
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [360]	valid_0's binary_logloss: 0.0054405
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [361]	valid_0's binary_logloss: 0.00544128
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [362]	valid_0's binary_logloss: 0.00544457
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [363]	valid_0's binary_logloss: 0.00544562
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [364]	valid_0's binary_logloss: 0.00544884
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [365]	valid_0's binary_logloss: 0.00545205
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [366]	valid_0's binary_logloss: 0.00545286
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [367]	valid_0's binary_logloss: 0.00546025
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [368]	valid_0's binary_logloss: 0.00546268
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [369]	valid_0's binary_logloss: 0.00546243
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [370]	valid_0's binary_logloss: 0.00546254
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [371]	valid_0's binary_logloss: 0.00546146
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [372]	valid_0's binary_logloss: 0.0054666
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [373]	valid_0's binary_logloss: 0.00546737
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [374]	valid_0's binary_logloss: 0.00546905
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [375]	valid_0's binary_logloss: 0.00546932
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [376]	valid_0's binary_logloss: 0.00546817
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [377]	valid_0's binary_logloss: 0.00546832
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [378]	valid_0's binary_logloss: 0.00547092
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [379]	valid_0's binary_logloss: 0.00547453
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [380]	valid_0's binary_logloss: 0.00547421
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [381]	valid_0's binary_logloss: 0.00547568
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [382]	valid_0's binary_logloss: 0.00547824
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [383]	valid_0's binary_logloss: 0.00547828
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [384]	valid_0's binary_logloss: 0.00547945
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [385]	valid_0's binary_logloss: 0.00548159
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [386]	valid_0's binary_logloss: 0.00548309
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [387]	valid_0's binary_logloss: 0.0054867
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [388]	valid_0's binary_logloss: 0.00548878
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [389]	valid_0's binary_logloss: 0.00548678
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [390]	valid_0's binary_logloss: 0.00548922
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [391]	valid_0's binary_logloss: 0.00549147
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [392]	valid_0's binary_logloss: 0.00549184
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [393]	valid_0's binary_logloss: 0.00549313
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [394]	valid_0's binary_logloss: 0.00549592
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [395]	valid_0's binary_logloss: 0.00549834
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [396]	valid_0's binary_logloss: 0.00549943
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [397]	valid_0's binary_logloss: 0.00549972
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [398]	valid_0's binary_logloss: 0.00550219
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [399]	valid_0's binary_logloss: 0.00550081
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [400]	valid_0's binary_logloss: 0.00550147
# LGBMClassifier(boost_from_average=False, force_col_wise=True, n_estimators=400)
# 오차행렬 :  [[85288     7]
#  [   29   116]]
# 정확도: 0.9996, 정밀도: 0.9431,  재현율: 0.8000, F1 Score: 0.8657, ROC_AUC : 0.9735

# %%
# (5) 로그변환 (O) / 이상치 제거 (O) / 오버샘플링 (O) / early_stopping(100) (X) 

from lightgbm import LGBMClassifier, early_stopping, log_evaluation
from imblearn.over_sampling import SMOTE

df_copy = card_df.copy()

# 로그변환 


# 이상치 데이터 삭제
  

X_train, X_test, y_train, y_test = get_train_test_dataset(df_copy)

# 오버 샘플링


print('LightGBM 예측 성능')

lgbm_clf = LGBMClassifier(n_estimators=400, 
                          boost_from_average=False,
                          force_col_wise=True) # , force_col_wise=True

eval_data = [(X_test, y_test)]

lgbm_clf.fit(X_train_over, y_train_over, 
            callbacks=[log_evaluation()],
            eval_metric='logloss', 
            eval_set=eval_data)

y_pred = lgbm_clf.predict(X_test)
pred_proba = lgbm_clf.predict_proba(X_test)[:, 1]

get_clf_eval(y_test, y_pred, pred_proba)
# Out:
# LightGBM 예측 성능
# [LightGBM] [Info] Number of positive: 199020, number of negative: 199020
# [LightGBM] [Info] Total Bins 7650
# [LightGBM] [Info] Number of data points in the train set: 398040, number of used features: 30
# [1]	valid_0's binary_logloss: 0.606531
# [2]	valid_0's binary_logloss: 0.535053
# [3]	valid_0's binary_logloss: 0.474891
# [4]	valid_0's binary_logloss: 0.424121
# [5]	valid_0's binary_logloss: 0.379741
# [6]	valid_0's binary_logloss: 0.341129
# [7]	valid_0's binary_logloss: 0.308033
# [8]	valid_0's binary_logloss: 0.278779
# [9]	valid_0's binary_logloss: 0.253169
# [10]	valid_0's binary_logloss: 0.230123
# [11]	valid_0's binary_logloss: 0.209798
# [12]	valid_0's binary_logloss: 0.191882
# [13]	valid_0's binary_logloss: 0.175705
# [14]	valid_0's binary_logloss: 0.161416
# [15]	valid_0's binary_logloss: 0.148459
# [16]	valid_0's binary_logloss: 0.136546
# [17]	valid_0's binary_logloss: 0.126051
# [18]	valid_0's binary_logloss: 0.116741
# [19]	valid_0's binary_logloss: 0.108037
# [20]	valid_0's binary_logloss: 0.1004
# [21]	valid_0's binary_logloss: 0.0932573
# [22]	valid_0's binary_logloss: 0.0867337
# [23]	valid_0's binary_logloss: 0.0809063
# [24]	valid_0's binary_logloss: 0.0751407
# [25]	valid_0's binary_logloss: 0.0702849
# [26]	valid_0's binary_logloss: 0.065805
# [27]	valid_0's binary_logloss: 0.061732
# [28]	valid_0's binary_logloss: 0.0577231
# [29]	valid_0's binary_logloss: 0.0541535
# [30]	valid_0's binary_logloss: 0.0509821
# [31]	valid_0's binary_logloss: 0.0479506
# [32]	valid_0's binary_logloss: 0.0452754
# [33]	valid_0's binary_logloss: 0.0426469
# [34]	valid_0's binary_logloss: 0.0403625
# [35]	valid_0's binary_logloss: 0.038193
# [36]	valid_0's binary_logloss: 0.0360133
# [37]	valid_0's binary_logloss: 0.0340037
# [38]	valid_0's binary_logloss: 0.0323203
# [39]	valid_0's binary_logloss: 0.0307293
# [40]	valid_0's binary_logloss: 0.0291696
# [41]	valid_0's binary_logloss: 0.027737
# [42]	valid_0's binary_logloss: 0.0263752
# [43]	valid_0's binary_logloss: 0.0251803
# [44]	valid_0's binary_logloss: 0.0239682
# [45]	valid_0's binary_logloss: 0.0228676
# [46]	valid_0's binary_logloss: 0.0218762
# [47]	valid_0's binary_logloss: 0.0209526
# [48]	valid_0's binary_logloss: 0.0200293
# [49]	valid_0's binary_logloss: 0.0191863
# [50]	valid_0's binary_logloss: 0.0184382
# [51]	valid_0's binary_logloss: 0.0177728
# [52]	valid_0's binary_logloss: 0.0170665
# [53]	valid_0's binary_logloss: 0.0163598
# [54]	valid_0's binary_logloss: 0.0157911
# [55]	valid_0's binary_logloss: 0.0152221
# [56]	valid_0's binary_logloss: 0.0146784
# [57]	valid_0's binary_logloss: 0.014178
# [58]	valid_0's binary_logloss: 0.0136615
# [59]	valid_0's binary_logloss: 0.0132024
# [60]	valid_0's binary_logloss: 0.0127912
# [61]	valid_0's binary_logloss: 0.0124389
# [62]	valid_0's binary_logloss: 0.0120675
# [63]	valid_0's binary_logloss: 0.0117035
# [64]	valid_0's binary_logloss: 0.0113746
# [65]	valid_0's binary_logloss: 0.011045
# [66]	valid_0's binary_logloss: 0.0107331
# [67]	valid_0's binary_logloss: 0.0104768
# [68]	valid_0's binary_logloss: 0.0101902
# [69]	valid_0's binary_logloss: 0.00990219
# [70]	valid_0's binary_logloss: 0.00962003
# [71]	valid_0's binary_logloss: 0.0093724
# [72]	valid_0's binary_logloss: 0.0091423
# [73]	valid_0's binary_logloss: 0.00887638
# [74]	valid_0's binary_logloss: 0.00823767
# [75]	valid_0's binary_logloss: 0.00779137
# [76]	valid_0's binary_logloss: 0.00766546
# [77]	valid_0's binary_logloss: 0.00747864
# [78]	valid_0's binary_logloss: 0.00727628
# [79]	valid_0's binary_logloss: 0.00711993
# [80]	valid_0's binary_logloss: 0.0069402
# [81]	valid_0's binary_logloss: 0.00679733
# [82]	valid_0's binary_logloss: 0.00662819
# [83]	valid_0's binary_logloss: 0.00649476
# [84]	valid_0's binary_logloss: 0.00634455
# [85]	valid_0's binary_logloss: 0.00621061
# [86]	valid_0's binary_logloss: 0.0060644
# [87]	valid_0's binary_logloss: 0.00595513
# [88]	valid_0's binary_logloss: 0.00583851
# [89]	valid_0's binary_logloss: 0.00574028
# [90]	valid_0's binary_logloss: 0.00563978
# [91]	valid_0's binary_logloss: 0.00556433
# [92]	valid_0's binary_logloss: 0.00548749
# [93]	valid_0's binary_logloss: 0.00539867
# [94]	valid_0's binary_logloss: 0.00543907
# [95]	valid_0's binary_logloss: 0.00532853
# [96]	valid_0's binary_logloss: 0.00524985
# [97]	valid_0's binary_logloss: 0.00519213
# [98]	valid_0's binary_logloss: 0.00509929
# [99]	valid_0's binary_logloss: 0.00504193
# [100]	valid_0's binary_logloss: 0.00499434
# [101]	valid_0's binary_logloss: 0.00491987
# [102]	valid_0's binary_logloss: 0.00484211
# [103]	valid_0's binary_logloss: 0.00481166
# [104]	valid_0's binary_logloss: 0.00474924
# [105]	valid_0's binary_logloss: 0.00468251
# [106]	valid_0's binary_logloss: 0.00463131
# [107]	valid_0's binary_logloss: 0.00458334
# [108]	valid_0's binary_logloss: 0.00453788
# [109]	valid_0's binary_logloss: 0.00448666
# [110]	valid_0's binary_logloss: 0.0044266
# [111]	valid_0's binary_logloss: 0.00439389
# [112]	valid_0's binary_logloss: 0.00434795
# [113]	valid_0's binary_logloss: 0.00430355
# [114]	valid_0's binary_logloss: 0.00425845
# [115]	valid_0's binary_logloss: 0.00422784
# [116]	valid_0's binary_logloss: 0.0041811
# [117]	valid_0's binary_logloss: 0.00413062
# [118]	valid_0's binary_logloss: 0.00409312
# [119]	valid_0's binary_logloss: 0.00405692
# [120]	valid_0's binary_logloss: 0.00401429
# [121]	valid_0's binary_logloss: 0.00397593
# [122]	valid_0's binary_logloss: 0.00395135
# [123]	valid_0's binary_logloss: 0.00391672
# [124]	valid_0's binary_logloss: 0.00389186
# [125]	valid_0's binary_logloss: 0.00385673
# [126]	valid_0's binary_logloss: 0.00382359
# [127]	valid_0's binary_logloss: 0.00379861
# [128]	valid_0's binary_logloss: 0.00377538
# [129]	valid_0's binary_logloss: 0.0037383
# [130]	valid_0's binary_logloss: 0.0037084
# [131]	valid_0's binary_logloss: 0.00369137
# [132]	valid_0's binary_logloss: 0.00366678
# [133]	valid_0's binary_logloss: 0.00365069
# [134]	valid_0's binary_logloss: 0.00364055
# [135]	valid_0's binary_logloss: 0.00362802
# [136]	valid_0's binary_logloss: 0.00360692
# [137]	valid_0's binary_logloss: 0.00359254
# [138]	valid_0's binary_logloss: 0.00356988
# [139]	valid_0's binary_logloss: 0.00355513
# [140]	valid_0's binary_logloss: 0.00354076
# [141]	valid_0's binary_logloss: 0.00351837
# [142]	valid_0's binary_logloss: 0.00350739
# [143]	valid_0's binary_logloss: 0.00350894
# [144]	valid_0's binary_logloss: 0.00349996
# [145]	valid_0's binary_logloss: 0.00348649
# [146]	valid_0's binary_logloss: 0.00346645
# [147]	valid_0's binary_logloss: 0.00345679
# [148]	valid_0's binary_logloss: 0.00345111
# [149]	valid_0's binary_logloss: 0.00343992
# [150]	valid_0's binary_logloss: 0.00342717
# [151]	valid_0's binary_logloss: 0.00341098
# [152]	valid_0's binary_logloss: 0.0034088
# [153]	valid_0's binary_logloss: 0.00340967
# [154]	valid_0's binary_logloss: 0.00338908
# [155]	valid_0's binary_logloss: 0.00337981
# [156]	valid_0's binary_logloss: 0.00336446
# [157]	valid_0's binary_logloss: 0.00335996
# [158]	valid_0's binary_logloss: 0.00334885
# [159]	valid_0's binary_logloss: 0.00333058
# [160]	valid_0's binary_logloss: 0.00332509
# [161]	valid_0's binary_logloss: 0.00331855
# [162]	valid_0's binary_logloss: 0.00331503
# [163]	valid_0's binary_logloss: 0.00330847
# [164]	valid_0's binary_logloss: 0.0033012
# [165]	valid_0's binary_logloss: 0.00330462
# [166]	valid_0's binary_logloss: 0.00328849
# [232]	valid_0's binary_logloss: 0.00330224
# [233]	valid_0's binary_logloss: 0.00330138
# [234]	valid_0's binary_logloss: 0.00329717
# [235]	valid_0's binary_logloss: 0.00330347
# [236]	valid_0's binary_logloss: 0.00330218
# [237]	valid_0's binary_logloss: 0.00330055
# [238]	valid_0's binary_logloss: 0.00330124
# [239]	valid_0's binary_logloss: 0.00330735
# [240]	valid_0's binary_logloss: 0.00331518
# [241]	valid_0's binary_logloss: 0.00331944
# [242]	valid_0's binary_logloss: 0.00332323
# [243]	valid_0's binary_logloss: 0.00333002
# [244]	valid_0's binary_logloss: 0.00333967
# [245]	valid_0's binary_logloss: 0.0033441
# [246]	valid_0's binary_logloss: 0.00335088
# [247]	valid_0's binary_logloss: 0.00335795
# [248]	valid_0's binary_logloss: 0.00336295
# [249]	valid_0's binary_logloss: 0.00337018
# [250]	valid_0's binary_logloss: 0.00337186
# [251]	valid_0's binary_logloss: 0.00337835
# [252]	valid_0's binary_logloss: 0.00337895
# [253]	valid_0's binary_logloss: 0.00338306
# [254]	valid_0's binary_logloss: 0.00338135
# [255]	valid_0's binary_logloss: 0.00338387
# [256]	valid_0's binary_logloss: 0.00338692
# [257]	valid_0's binary_logloss: 0.00338578
# [258]	valid_0's binary_logloss: 0.00338799
# [259]	valid_0's binary_logloss: 0.00339141
# [260]	valid_0's binary_logloss: 0.00339837
# [261]	valid_0's binary_logloss: 0.00340889
# [262]	valid_0's binary_logloss: 0.00341313
# [263]	valid_0's binary_logloss: 0.00341942
# [264]	valid_0's binary_logloss: 0.00341851
# [265]	valid_0's binary_logloss: 0.00341851
# [266]	valid_0's binary_logloss: 0.00342576
# [267]	valid_0's binary_logloss: 0.0034264
# [268]	valid_0's binary_logloss: 0.00343046
# [269]	valid_0's binary_logloss: 0.00343639
# [270]	valid_0's binary_logloss: 0.00343053
# [271]	valid_0's binary_logloss: 0.00342957
# [272]	valid_0's binary_logloss: 0.00342967
# [273]	valid_0's binary_logloss: 0.00343297
# [274]	valid_0's binary_logloss: 0.0034387
# [275]	valid_0's binary_logloss: 0.00344535
# [276]	valid_0's binary_logloss: 0.00345291
# [277]	valid_0's binary_logloss: 0.00345557
# [278]	valid_0's binary_logloss: 0.00346167
# [279]	valid_0's binary_logloss: 0.00346678
# [280]	valid_0's binary_logloss: 0.00347359
# [281]	valid_0's binary_logloss: 0.0034735
# [282]	valid_0's binary_logloss: 0.00347126
# [283]	valid_0's binary_logloss: 0.00347182
# [284]	valid_0's binary_logloss: 0.00347583
# [285]	valid_0's binary_logloss: 0.00347908
# [286]	valid_0's binary_logloss: 0.00348871
# [287]	valid_0's binary_logloss: 0.00349435
# [288]	valid_0's binary_logloss: 0.00350237
# [289]	valid_0's binary_logloss: 0.0035076
# [290]	valid_0's binary_logloss: 0.00351688
# [291]	valid_0's binary_logloss: 0.00351799
# [292]	valid_0's binary_logloss: 0.0035212
# [293]	valid_0's binary_logloss: 0.00352164
# [294]	valid_0's binary_logloss: 0.00353207
# [295]	valid_0's binary_logloss: 0.00353756
# [296]	valid_0's binary_logloss: 0.00354288
# [297]	valid_0's binary_logloss: 0.00355147
# [298]	valid_0's binary_logloss: 0.00355064
# [299]	valid_0's binary_logloss: 0.00355688
# [300]	valid_0's binary_logloss: 0.00356789
# [301]	valid_0's binary_logloss: 0.00357075
# [302]	valid_0's binary_logloss: 0.0035716
# [303]	valid_0's binary_logloss: 0.00357764
# [304]	valid_0's binary_logloss: 0.0035788
# [305]	valid_0's binary_logloss: 0.00358441
# [306]	valid_0's binary_logloss: 0.00358864
# [307]	valid_0's binary_logloss: 0.0035893
# [308]	valid_0's binary_logloss: 0.00360025
# [309]	valid_0's binary_logloss: 0.00361149
# [310]	valid_0's binary_logloss: 0.00361334
# [311]	valid_0's binary_logloss: 0.00362408
# [312]	valid_0's binary_logloss: 0.00362133
# [313]	valid_0's binary_logloss: 0.00362823
# [314]	valid_0's binary_logloss: 0.00363469
# [315]	valid_0's binary_logloss: 0.00364243
# [316]	valid_0's binary_logloss: 0.00364576
# [317]	valid_0's binary_logloss: 0.0036539
# [318]	valid_0's binary_logloss: 0.00365628
# [319]	valid_0's binary_logloss: 0.00365906
# [320]	valid_0's binary_logloss: 0.00366581
# [321]	valid_0's binary_logloss: 0.00366917
# [322]	valid_0's binary_logloss: 0.00367779
# [323]	valid_0's binary_logloss: 0.00368656
# [324]	valid_0's binary_logloss: 0.0036935
# [325]	valid_0's binary_logloss: 0.00370868
# [326]	valid_0's binary_logloss: 0.00371585
# [327]	valid_0's binary_logloss: 0.00371883
# [328]	valid_0's binary_logloss: 0.00372036
# [329]	valid_0's binary_logloss: 0.00372353
# [330]	valid_0's binary_logloss: 0.00372618
# [331]	valid_0's binary_logloss: 0.00373415
# [332]	valid_0's binary_logloss: 0.00373998
# [333]	valid_0's binary_logloss: 0.00374253
# [334]	valid_0's binary_logloss: 0.00374686
# [335]	valid_0's binary_logloss: 0.00375352
# [336]	valid_0's binary_logloss: 0.00375338
# [337]	valid_0's binary_logloss: 0.00376104
# [338]	valid_0's binary_logloss: 0.00376186
# [339]	valid_0's binary_logloss: 0.0037687
# [340]	valid_0's binary_logloss: 0.00377601
# [341]	valid_0's binary_logloss: 0.0037793
# [342]	valid_0's binary_logloss: 0.00378619
# [343]	valid_0's binary_logloss: 0.00379254
# [344]	valid_0's binary_logloss: 0.00379864
# [345]	valid_0's binary_logloss: 0.00379946
# [346]	valid_0's binary_logloss: 0.00380541
# [347]	valid_0's binary_logloss: 0.00381494
# [348]	valid_0's binary_logloss: 0.00382315
# [349]	valid_0's binary_logloss: 0.00383119
# [350]	valid_0's binary_logloss: 0.00384153
# [351]	valid_0's binary_logloss: 0.00384904
# [352]	valid_0's binary_logloss: 0.00384904
# [353]	valid_0's binary_logloss: 0.00385396
# [354]	valid_0's binary_logloss: 0.00386083
# [355]	valid_0's binary_logloss: 0.00386742
# [356]	valid_0's binary_logloss: 0.00387251
# [357]	valid_0's binary_logloss: 0.00388643
# [358]	valid_0's binary_logloss: 0.00388566
# [359]	valid_0's binary_logloss: 0.00388584
# [360]	valid_0's binary_logloss: 0.00389739
# [361]	valid_0's binary_logloss: 0.00389775
# [362]	valid_0's binary_logloss: 0.0039025
# [363]	valid_0's binary_logloss: 0.00391059
# [364]	valid_0's binary_logloss: 0.00392064
# [365]	valid_0's binary_logloss: 0.00392235
# [366]	valid_0's binary_logloss: 0.00393001
# [367]	valid_0's binary_logloss: 0.0039369
# [368]	valid_0's binary_logloss: 0.00393487
# [369]	valid_0's binary_logloss: 0.00394251
# [370]	valid_0's binary_logloss: 0.00395535
# [371]	valid_0's binary_logloss: 0.00395853
# [372]	valid_0's binary_logloss: 0.00396577
# [373]	valid_0's binary_logloss: 0.00396756
# [374]	valid_0's binary_logloss: 0.00397111
# [375]	valid_0's binary_logloss: 0.00397956
# [376]	valid_0's binary_logloss: 0.00398717
# [377]	valid_0's binary_logloss: 0.00399816
# [378]	valid_0's binary_logloss: 0.00399714
# [379]	valid_0's binary_logloss: 0.00400669
# [380]	valid_0's binary_logloss: 0.00400847
# [381]	valid_0's binary_logloss: 0.00400582
# [382]	valid_0's binary_logloss: 0.00400955
# [383]	valid_0's binary_logloss: 0.00400965
# [384]	valid_0's binary_logloss: 0.00401647
# [385]	valid_0's binary_logloss: 0.0040209
# [386]	valid_0's binary_logloss: 0.0040291
# [387]	valid_0's binary_logloss: 0.00403539
# [388]	valid_0's binary_logloss: 0.0040433
# [389]	valid_0's binary_logloss: 0.00404566
# [390]	valid_0's binary_logloss: 0.00405417
# [391]	valid_0's binary_logloss: 0.00406296
# [392]	valid_0's binary_logloss: 0.00407056
# [393]	valid_0's binary_logloss: 0.00408121
# [394]	valid_0's binary_logloss: 0.00408726
# [395]	valid_0's binary_logloss: 0.00409398
# [396]	valid_0's binary_logloss: 0.00410135
# [397]	valid_0's binary_logloss: 0.00409668
# [398]	valid_0's binary_logloss: 0.0041055
# [399]	valid_0's binary_logloss: 0.00411123
# [400]	valid_0's binary_logloss: 0.00411561
# LGBMClassifier(boost_from_average=False, force_col_wise=True, n_estimators=400)
# 오차행렬 :  [[85283    12]
#  [   27   118]]
# 정확도: 0.9995, 정밀도: 0.9077,  재현율: 0.8138, F1 Score: 0.8582, ROC_AUC : 0.9808

# %%
# (6) # 로그변환 (O) / 이상치 제거 (O) / 오버샘플링 (O) / early_stopping(100) (O) 

from lightgbm import LGBMClassifier, early_stopping, log_evaluation
from imblearn.over_sampling import SMOTE

df_copy = card_df.copy()

# 로그변환 
amount = np.log1p(df_copy['Amount'])
df_copy.insert(0, 'Amount_log', amount)

# 이상치 데이터 삭제
outlier_index = get_outlier(df=df_copy, column='V14', weight=1.5)
df_copy.drop(outlier_index, axis=0, inplace=True)     

outlier_index = get_outlier(df=df_copy, column='V12', weight=1.5)
df_copy.drop(outlier_index, axis=0, inplace=True)     

X_train, X_test, y_train, y_test = get_train_test_dataset(df_copy)

# 오버 샘플링
smote = SMOTE(random_state=0)
# 학습용 데이터 세트에만 오버샘플링 적용
X_train_over, y_train_over = smote.fit_resample(X_train, y_train)


print('LightGBM 예측 성능')

lgbm_clf = LGBMClassifier(n_estimators=400, 
                          boost_from_average=False,
                          force_col_wise=True) # , force_col_wise=True

eval_data = [(X_test, y_test)]


y_pred = lgbm_clf.predict(X_test)
pred_proba = lgbm_clf.predict_proba(X_test)[:, 1]

get_clf_eval(y_test, y_pred, pred_proba)

# 오차행렬 :  [[85270    25]
#  [   25   120]]
# 정확도: 0.9994, 정밀도: 0.8276,  재현율: 0.8276, F1 Score: 0.8276, ROC_AUC : 0.9801
# Out:
# LightGBM 예측 성능
# [LightGBM] [Info] Number of positive: 199020, number of negative: 199020
# [LightGBM] [Info] Total Bins 7650
# [LightGBM] [Info] Number of data points in the train set: 398040, number of used features: 30
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [198]	valid_0's binary_logloss: 0.00321513
# LGBMClassifier(boost_from_average=False, force_col_wise=True, n_estimators=400)
# 오차행렬 :  [[85270    25]
#  [   25   120]]
# 정확도: 0.9994, 정밀도: 0.8276,  재현율: 0.8276, F1 Score: 0.8276, ROC_AUC : 0.9801

# %%
# (1) 아무 것도 하지 않은 경우
# 로그변환 (X) / 이상치 제거 (X) / 오버샘플링 (X) / early_stopping(100) (X) 

# 오차행렬 :  [[85291     4]
#  [   37   111]]
# 정확도: 0.9995, 정밀도: 0.9652,  재현율: 0.7500, F1 Score: 0.8441, ROC_AUC : 0.9805

# (2) 로그변환 (X) / 이상치 제거 (X) / 오버샘플링 (O) / early_stopping(100) (X) 

# 오차행렬 :  [[85285    10]
#  [   32   116]]
# 정확도: 0.9995, 정밀도: 0.9206,  재현율: 0.7838, F1 Score: 0.8467, ROC_AUC : 0.9552

# (3) 로그변환 (X) / 이상치 제거 (X) / 오버샘플링 (O) / early_stopping(100) (O) 
# 오차행렬 :  [[85233    62]
#  [   23   125]]
# 정확도: 0.9990, 정밀도: 0.6684,  재현율: 0.8446, F1 Score: 0.7463, ROC_AUC : 0.9779
# 재현율은 상당히 향상되었지만 정밀도가 많이 낮아졌고, 따라서 F1 Score 수치도 낮아짐 
# 사기 검출 데이터에서는 재현율에 초점을 맞춰서 진행하는 것이 더 좋으므로 
# 정밀도와 F1 Score를 희생하더라도 재현율을 높이는 것이 바람직함 

# (4) 로그변환 (O) / 이상치 제거 (O) / 오버샘플링 (X) / early_stopping(100) (X) 
# 오차행렬 :  [[85288     7]
#  [   29   116]]
# 정확도: 0.9996, 정밀도: 0.9431,  재현율: 0.8000, F1 Score: 0.8657, ROC_AUC : 0.9735

# (5) 로그변환 (O) / 이상치 제거 (O) / 오버샘플링 (O) / early_stopping(100) (X) 

# 오차행렬 :  [[85283    12]
#  [   27   118]]
# 정확도: 0.9995, 정밀도: 0.9077,  재현율: 0.8138, F1 Score: 0.8582, ROC_AUC : 0.9808

# (6) # 로그변환 (O) / 이상치 제거 (O) / 오버샘플링 (O) / early_stopping(100) (O) 

# 오차행렬 :  [[85270    25]
#  [   25   120]]
# 정확도: 0.9994, 정밀도: 0.8276,  재현율: 0.8276, F1 Score: 0.8276, ROC_AUC : 0.9801
# (3)번보다 재현율이 약2% 정도 낮지만 정밀도, F1 Score 등 전반적으로 균형이루고 있으므로
# 좋은 선택이 될 수 있음
