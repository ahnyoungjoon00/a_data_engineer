# %% [markdown]
# ## 규제 선형 모델 - 릿지, 라쏘, 엘라스틱넷
# Regularized Linear Models - Ridge, Lasso, Elastic Net

# %% [markdown]
#
# 선형 모델의 비용 함수
# - RSS 최소화 : 실제값과 예측값의 차이를 최소화
# - RSS를 최소하는 것만 고려하면 과적합되고 회귀 계수가 쉽게 커지고
# - 이에 따라서 변동성이 심해져서 예측 성능이 저하되기 쉬움
# - 따라서 RSS 최소화 방법과 과적합 방지를 위해
# - 회귀 계수값이 커지지 않도록 하는 균형적인 방법 필요
#
# 최적 모델을 위한 비용 함수 구성요소 = RSS 최소화 + 회귀 계수 크기 제어
# -> 학습 데이터 정도와 회귀 계수 값의 크기 제어를 수행하는 튜닝 파리미터 사용 (alpha)
#
# ---
# 선형 회귀 모델에서
#   - 비용함수 : 실제값과 예측값의 차이를 최소화하는 것을 목표
#   - 학습 테이터에 지나치게 맞추게 되면, 회귀 계수가 쉽계 커지는 현상 발생(과적합)
#   - 비용함수 최소화하고 회귀 계수는 커지지 않도록 유지하는 것이 필요한데
#     - 이때 회귀 계수의 값의 크기를 제어하기 위해 alpha 파라미터 사용
#       - alpha 값을 크게 해서 회기 계수를 작게하여 과적합을 개선

# %% [markdown]
# ### 규제
# - 비용함수에 alpha 값으로 패널티를 부여해서
# - 회귀 계수 값의 크기를 감소시켜 과적합을 개선하는 방식
# - L2 방식과 L1 방식
#
# L2 규제
# - 회귀 계수 값의 제곱에 대해 패널티를 부여하는 방식
# - 회귀 계수의 크기 감소
# - L2 규제를 적용한 회귀 : 릿지(Redge) 방식
#
# L1 규제
# - 회귀 계수의 절대값에 대해 패널티를 부여하는 방식
# - 영향력이 크지 않은 회귀 계수를 0으로 변환하고 제거
#   - 적절한 피처만 회귀에 포함시키는 피처 선택의 특성
# - L1 규제를 적용한 회귀 : 라쏘(Lasso) 회귀
#
#
# Elastic Net : L2, L1 규제를 함께 결합한 모델
# - 주로 피처가 많은 데이터 세트에서 적용
# - L1 규제로 피처의 개수를 줄임과 동시에
# - L2 규제로 계수 값의 크기 조정

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"

# %% [markdown]
# ### 데이터 준비

# %%
import numpy as np
import pandas as pd
import seaborn as sns
# from sklearn.datasets import load_boston
import matplotlib.pyplot as plt
# %matplotlib inline

boston_df = df_pop = pd.read_csv('./data/boston_dataset.csv', index_col=0) 
boston_df.head()
boston_df.tail()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  PRICE
# 0  396.90   4.98   24.0
# 1  396.90   9.14   21.6
# 2  392.83   4.03   34.7
# 3  394.63   2.94   33.4
# 4  396.90   5.33   36.2
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0
#
#           B  LSTAT  PRICE
# 501  391.99   9.67   22.4
# 502  396.90   9.08   20.6
# 503  396.90   5.64   23.9
# 504  393.45   6.48   22.0
# 505  396.90   7.88   11.9

# %%
plt.figure(figsize=(8, 6))
sns.histplot(boston_df["PRICE"], kde=True)
plt.show()
# Out:
# <Axes: xlabel='PRICE', ylabel='Count'>

# %%
boston_price = np.log1p(boston_df["PRICE"])
plt.figure(figsize=(8, 6))
sns.histplot(boston_price, kde=True)
plt.show()
# Out:
# <Axes: xlabel='PRICE', ylabel='Count'>

# %%
from scipy import stats
plt.figure(figsize=(8, 6))
sns.distplot(boston_price, kde=True, fit=stats.norm)
plt.show()
# Out:
# C:\Users\82108\AppData\Local\Temp\ipykernel_30912\2592195085.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(boston_price, kde=True, fit=stats.norm)
# <Axes: xlabel='PRICE', ylabel='Density'>

# %%
boston_df["PRICE"] = boston_price
boston_df.head(3)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
#
#         B  LSTAT     PRICE
# 0  396.90   4.98  3.218876
# 1  396.90   9.14  3.117950
# 2  392.83   4.03  3.575151

# %% [markdown]
# - CRIM(범죄율): Per capita crime rate by town
# - ZN(25000평방미터 당 주거지 비율):
#     - Proportion of residential land zoned for lots over 25,000 sq. ft
# - INDUS(도매사업비율): Proportion of non-retail business acres per town
# - CHAS(찰스강뷰) : Charles River dummy variable (1 if tract bounds river; 0 otherwise)
# - NOX(질산: Nitric oxide concentration (parts per 10 million)
# - RM: Average number of rooms per dwelling
# - AGE: Proportion of owner-occupied units built prior to 1940
# - DIS: Weighted distances to five Boston employment centers
# - RAD: Index of accessibility to radial highways
# - PTRATIO: Pupil-teacher ratio by town
# - B: 1000(Bk — 0.63)², where Bk is the proportion of [people of African American descent] by town
# - LSTAT: Percentage of lower status of the population
# - MEDV: Median value of owner-occupied homes in $1000s

# %%
boston_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  PRICE    506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 59.3 KB

# %%
# 타깃값 데이터 셋 만들기
y_target = boston_df['PRICE']

# 피처값 데이터 셋 만들기
# 타깃 제외한 나머지 칼럼들
X_data = boston_df.drop(['PRICE'], axis=1, inplace=False)

# %%
from sklearn.model_selection import train_test_split

X_train , X_test , y_train , y_test = train_test_split(X_data ,
                                                       y_target,
                                                       test_size=0.3, 
                                                       random_state=156)

# %% [markdown]
# ###  (1) Ridge 회귀
# - 회귀 계수 값의 제곱에 대해 패널티를 부여하는 L2 규제를 선형 회귀에 적용한 것
# - 사이킷런의 Ridge 클래스 사용해서 릿지 회귀 구현
# - 주요 생성 파라미터는 alpha: alpha L2 규제 계수에 해당

# %%
# Ridge 모델 생성/학습/예측

from sklearn.linear_model import Ridge

ridge = Ridge(alpha=10)
ridge.fit(X_train, y_train)
y_pred = ridge.predict(X_test)
# Out:
# Ridge(alpha=10)

# %%
# Ridge 모델 평가
from sklearn.metrics import mean_squared_error, r2_score, root_mean_squared_error

# rmse 구하기
rmse = root_mean_squared_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

# R제곱 : r2_score() 사용
r2 = r2_score(y_test, y_pred)

# 평가 지표 출력
print(f"MSE : {mse:.4F}, RMSE : {rmse:.4f}")
print(f"R제곱 : {r2:.4f}")

# 단순 선형 회귀 모델 결과  : LinearRegression
# MSE : 17.2969, RMSE : 4.1590
# R제곱 : 0.7572

# 릿지 모델 결과
# MSE : 17.6987, RMSE : 4.2070
# R제곱 : 0.7516

# Ridge 모델과 LinearRegression 모델 결과 큰 차이 없음
# Out:
# MSE : 17.6987, RMSE : 4.2070
# R제곱 : 0.7516

# %%
# 교차 검증 수행 

from sklearn.model_selection import cross_val_score

# 5개 Fold 셋으로 MSE 구함 
neg_mse_scores = cross_val_score(ridge,
                                 X_data, y_target,
                                 scoring="neg_mean_squared_error",
                                 cv=5)

# neg_mean_squared_error가 음수값으로 반환되므로 -1을 곱해서 사용
# RMSE는 np.sqrt() 사용
rmse_scores = np.sqrt(-1 * neg_mse_scores)
avg_rmse = np.mean(rmse_scores)

# 평가 지표 출력
print('5 Folds 교차검증 개별 Negative MSE scores : ', np.round(neg_mse_scores, 2))
print('5 Folds 교차검증 개별 RMSE scores : ', np.round(rmse_scores, 2))
print('5 Folds 교차검증 평균 RMSE : ', np.round(avg_rmse, 3))
# Out:
# 5 Folds 교차검증 개별 Negative MSE scores :  [-11.42 -24.29 -28.14 -74.6  -28.52]
# 5 Folds 교차검증 개별 RMSE scores :  [3.38 4.93 5.31 8.64 5.34]
# 5 Folds 교차검증 평균 RMSE :  5.518

# %%
# alpha 값을 [0, 0.1,1, 10, 100]으로 변경하면서
# RMSE와 회귀 계수 값의 변화 확인

# %%
# Ridge에 사용할 alpha 파라미터 설정
alphas = [0, 0.1, 1, 10, 100]

# alpha 값에 따른 평균 RMSE 구하기 
for alpha in alphas:
    ridge = Ridge(alpha=alpha)
    neg_mse_scores = cross_val_score(ridge,
                                 X_data, y_target,
                                 scoring="neg_mean_squared_error",
                                 cv=5)
    
    rmse_scores = np.sqrt(-1 * neg_mse_scores)
    avg_rmse = np.mean(rmse_scores)
    print(f'alpha {alpha} 일 때 5 Folds 교차검증 평균 RMSE : {avg_rmse:.4f}')
    
# alpha 값이 커질수록 RMSE가 줄어드는 것 확인 : 성능이 좋아짐
# alpha 값이 100일 때 RMSE : 5.3296으로 가장 좋음
# Out:
# alpha 0 일 때 5 Folds 교차검증 평균 RMSE : 5.8287
# alpha 0.1 일 때 5 Folds 교차검증 평균 RMSE : 5.7885
# alpha 1 일 때 5 Folds 교차검증 평균 RMSE : 5.6526
# alpha 10 일 때 5 Folds 교차검증 평균 RMSE : 5.5182
# alpha 100 일 때 5 Folds 교차검증 평균 RMSE : 5.3296

# %%
# 가장 좋은 결과가 나온 100을 기준으로 다시 모델 생성/학습/예측
ridge = Ridge(alpha=100)
ridge.fit(X_train, y_train)
y_pred = ridge.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)

# 평가지표 출력
print(f'MSE : {mse:.3f}, RMSE : {rmse:.3f}')
print(f'R제곱 : {r2_score(y_test, y_pred):.3f}')


# 이전 릿지 모델 결과
# MSE : 17.6987, RMSE : 4.2070
# R제곱 : 0.7516

# 최적의 alpha 값으로 다시 모델링한 결과 
# MSE : 19.362, RMSE : 4.400
# R제곱 : 0.728

# 미미하게 RMSE이 커졌고, R제곱은 작아짐
# Out:
# Ridge(alpha=100)
# MSE : 19.362, RMSE : 4.400
# R제곱 : 0.728

# %% [markdown]
# ### 각 alpha 값에  따른 회귀 값을 시각화

# %%
# 각 alpha 값에  따른 회귀 값을 시각화
# alpha 값의 변화에 따른 피처의 회귀 계수 값을 가로 막대 그래프로 시각화

alphas = [0, 0.1, 1, 10, 100]

# 각 alpha 값(5개)에 따른 회귀 계수값을 시각화하기 위해 5열로 된 축 생성 
fig, axs = plt.subplots(figsize=(18, 6), nrows=1, ncols=5)

# 각 alpha값을 df로 저장
coef_df = pd.DataFrame()

for pos, alpha in enumerate(alphas):
    ridge = Ridge(alpha = alpha)
    ridge.fit(X_data, y_target) # 전체 데이터
    # 회귀계수 df에 추가
    coef = pd.Series(data=ridge.coef_, index=X_data.columns)
    colname = "alpha:"+ str(alpha)
    coef_df[colname]= coef
    
    # df에 추가
    coef = coef.sort_values(ascending=False)

    # 막대 그래프로 회귀 계수 시각화 : 정렬 후 줓ㄹ력
    axs[pos].set_title(colname)
    axs[pos].set_xlim(-3, 6)
    sns.barplot(x=coef.values, y=coef.index, ax=axs[pos])
    
plt.show()

# alpha 값이 커지면 피처의 회귀 계수가 작아지는 것 확인 
# 가장 상관관계가 높은 RM의 값은 반정도 줄었고
# NOX의 회귀 계수가 상당히 컸었는데 거의 1/3 정도로 줄었음
# 따라서 alpha 값이 회귀 계수가 커지는 것을 막고 성능을 향상킨다는 것 확인했음
# Out:
# Ridge(alpha=0)
# Text(0.5, 1.0, 'alpha:0')
# (-3.0, 6.0)
# <Axes: title={'center': 'alpha:0'}, ylabel='None'>
# Ridge(alpha=0.1)
# Text(0.5, 1.0, 'alpha:0.1')
# (-3.0, 6.0)
# <Axes: title={'center': 'alpha:0.1'}, ylabel='None'>
# Ridge(alpha=1)
# Text(0.5, 1.0, 'alpha:1')
# (-3.0, 6.0)
# <Axes: title={'center': 'alpha:1'}, ylabel='None'>
# Ridge(alpha=10)
# Text(0.5, 1.0, 'alpha:10')
# (-3.0, 6.0)
# <Axes: title={'center': 'alpha:10'}, ylabel='None'>
# Ridge(alpha=100)
# Text(0.5, 1.0, 'alpha:100')
# (-3.0, 6.0)
# <Axes: title={'center': 'alpha:100'}, ylabel='None'>

# %%
coef_df.head(3)
# Out:
#         alpha:0  alpha:0.1   alpha:1  alpha:10  alpha:100
# CRIM  -0.108011  -0.107474 -0.104595 -0.101435  -0.102202
# ZN     0.046420   0.046572  0.047443  0.049579   0.054496
# INDUS  0.020559   0.015999 -0.008805 -0.042962  -0.052826

# %%
# alpha:0 컬럼 기준 내림차순 정렬
coef_df.sort_values(by="alpha:0", ascending=False)

# 결과
# RM : 가장 회귀계수가 큰 컬럼, 규제 step에 따라 점차 회귀계수 작아짐
# NOX : 선형회귀에서 과적합으로 보였던 컬럼
# 규제 전 : -19 >> 규제 후 :
# 가장 큰 값을 상당히 줄이면서 적절한 수준으로 낮췄고, 점차 최적의 회귀모델이 만들어 질 수 있음
# alpha값 10, 100이 적절한 규제로 보여짐
# Out:
#            alpha:0  alpha:0.1    alpha:1  alpha:10  alpha:100
# RM        3.809865   3.818233   3.854000  3.702272   2.334536
# CHAS      2.686734   2.670019   2.552393  1.952021   0.638335
# RAD       0.306049   0.303515   0.290142  0.279596   0.315358
# ZN        0.046420   0.046572   0.047443  0.049579   0.054496
# INDUS     0.020559   0.015999  -0.008805 -0.042962  -0.052826
# B         0.009312   0.009368   0.009673  0.010037   0.009393
# AGE       0.000692  -0.000269  -0.005415 -0.010707   0.001212
# TAX      -0.012335  -0.012421  -0.012912 -0.013993  -0.015856
# CRIM     -0.108011  -0.107474  -0.104595 -0.101435  -0.102202
# LSTAT    -0.524758  -0.525966  -0.533343 -0.559366  -0.660764
# PTRATIO  -0.952747  -0.940759  -0.876074 -0.797945  -0.829218
# DIS      -1.475567  -1.459626  -1.372654 -1.248808  -1.153390
# NOX     -17.766611 -16.684645 -10.777015 -2.371619  -0.262847

# %% [markdown]
# ### 독립변수/종속변수의 분포를 변환해서 모델링 진행
# - 독립변수 표준스케일링 진행
# - 종속변수 로그변환 진행
# - Ridge 알고리즘 모델링 진행
# - alpha값 튜닝 (10, 100 포함해서) 진행

# %% [markdown]
# ### 참고
# - 선형 회귀 모델에서 비용함수는 실제값과 예측값의 차이를 최소화하는 것을 목표
# - 학습 데이터에 지나치게 맞추게 되면, 회귀 게수가 쉽게 커지는 현상이 발생
# - 비용함수는 최소화하고 회귀 계수는 커지지 않도록 유지하는 것이 필요한데
# - 이때 회귀 계수 값의 크기 제어를 수행하는 튜닝 파라미터 alpha 사용
# - 비용함수 목표 = Min(RSS + alpha * 회귀계수)
#     - alpha 값이 0 또는 매우 작으면 비용함수 Min(RSS)이 되고,
#     - alpha 값이 커지면 회귀 계수를 작게 해서 비용함수 목표를 이룰 수 있음
#     - 즉, alpha 값을 작게 하면 회귀 계수 값이 커져도 어느 정도 상쇄되고
#     - alpha 값을 크게하면 회수 계수를 작게해서 과적합을 개선

# %% [markdown]
# ## (2) 라쏘 (Lasso) 회귀
# - 회귀 계수의 절대값에 패널티를 부여하는 L1규제를 선형 회귀에 적용한 것
# - 영향력이 크지 않은 회귀 계수를 0으로 변환하고 제거
# - 적절한 피처만 회귀에 포함시키는 피처 선택의 특성
#
# - 사이킷런의 Lasso 클래스를 이용해서 라쏘 회귀 구현
# - 주요 생성 파라미터 alpha : 라소 회귀의 alpha L1 규제 계수 해당

# %%
# 라쏘 모델 생성/학습/예측
from sklearn.linear_model import Lasso

lasso = Lasso(alpha=10)
lasso.fit(X_train, y_train)
y_pred= lasso.predict(X_test)
# Out:
# Lasso(alpha=10)

# %%
# 평가 
from sklearn.metrics import mean_squared_error, r2_score, root_mean_squared_error

# rmse 구하기
rmse = root_mean_squared_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

# R제곱 : r2_score() 사용
r2 = r2_score(y_test, y_pred)

# 평가 지표 출력
print(f"MSE : {mse:.4F}, RMSE : {rmse:.4f}")
print(f"R제곱 : {r2:.4f}")

# 단순 선형 회귀 모델 결과  : LinearRegression
# MSE : 17.2969, RMSE : 4.1590
# R제곱 : 0.7572

# 릿지 모델 결과
# MSE : 17.6987, RMSE : 4.2070
# R제곱 : 0.7516

# 라쏘 모델 결과
# MSE : 33.0302, RMSE : 5.7472
# R제곱 : 0.5364

# 교차검증과 alpha 튜닝 전
# 라쏘 모델 성능이 제일 낮음
# Out:
# MSE : 33.0302, RMSE : 5.7472
# R제곱 : 0.5364

# %%
# 교차 검증 수행

from sklearn.model_selection import cross_val_score

# 5개 Fold 셋으로 MSE 구함 
neg_mse_scores = cross_val_score(lasso, # alpha값 10 임
                                 X_data, y_target,
                                 scoring='neg_mean_squared_error',
                                 cv=5)

rmse_scores = np.sqrt(-1 * neg_mse_scores)
avg_rmse = np.mean(rmse_scores)

# 평가 지표 출력
print('5 Folds 교차검증 개별 Negative MSE scores : ', np.round(neg_mse_scores, 2))
print('5 Folds 교차검증 개별 RMSE scores : ', np.round(rmse_scores, 2))
print('5 Folds 교차검증 평균 RMSE : ', np.round(avg_rmse, 3))
# Out:
# 5 Folds 교차검증 개별 Negative MSE scores :  [-27.79 -46.4  -80.32 -61.56 -16.3 ]
# 5 Folds 교차검증 개별 RMSE scores :  [5.27 6.81 8.96 7.85 4.04]
# 5 Folds 교차검증 평균 RMSE :  6.586

# %%
# alpha 값을 [0.07, 0.1, 0.5, 1, 3] 으로 변경하면서 
# RMSE와 회귀 계수 값의 변화 측정

alphas = [0.07, 0.1, 0.5, 1, 3]
# alphas = [0, 0.1, 1]
train_score = []
test_score = []

# alpha 값에 따른 평균 RMSE 구하기 
for alpha in alphas:
    lasso = Lasso(alpha=alpha)
    neg_mse_scores = cross_val_score(lasso,
                                     X_data, y_target,
                                     scoring="neg_mean_squared_error",
                                     cv=5)
    
    rmse_scores = np.sqrt(-1 * neg_mse_scores)
    avg_rmse = np.mean(rmse_scores)
    print(f'alpha {alpha} 일 때 5 Folds 교차검증 평균 RMSE : {avg_rmse:.4f}')
# Out:
# alpha 0.07 일 때 5 Folds 교차검증 평균 RMSE : 5.6123
# alpha 0.1 일 때 5 Folds 교차검증 평균 RMSE : 5.6151
# alpha 0.5 일 때 5 Folds 교차검증 평균 RMSE : 5.6691
# alpha 1 일 때 5 Folds 교차검증 평균 RMSE : 5.7760
# alpha 3 일 때 5 Folds 교차검증 평균 RMSE : 6.1888

# %%
# 각 alpha에 따른 회귀 계수 값을 시각화
# 각 alpha에 따른 회귀 계수 값을 시각화
fig, axs = plt.subplots(figsize=(18, 6), nrows=1, ncols=5)

# 각 alpha 값을 df로 저장
coeff_df2 = pd.DataFrame()

for pos, alpha in enumerate(alphas):
    lasso = Lasso(alpha=alpha) # 초기화
    lasso.fit(X_data, y_target) # 학습
    
    # df에 추가
    coeff = pd.Series(data=lasso.coef_, index=X_data.columns)
    colname = 'alpha:' + str(alpha)
    coeff_df2[colname] = coeff
    
    # 막대 그래프로 회귀 계수 시각화 : 정렬 후 출력
    coeff = coeff.sort_values(ascending=False)
    axs[pos].set_title(colname)
    axs[pos].set_xlim(-3, 6)
    sns.barplot(x=coeff.values, y=coeff.index, ax=axs[pos])
    
plt.show()
# Out:
# Lasso(alpha=0.07)
# Text(0.5, 1.0, 'alpha:0.07')
# (-3.0, 6.0)
# <Axes: title={'center': 'alpha:0.07'}, ylabel='None'>
# Lasso(alpha=0.1)
# Text(0.5, 1.0, 'alpha:0.1')
# (-3.0, 6.0)
# <Axes: title={'center': 'alpha:0.1'}, ylabel='None'>
# Lasso(alpha=0.5)
# Text(0.5, 1.0, 'alpha:0.5')
# (-3.0, 6.0)
# <Axes: title={'center': 'alpha:0.5'}, ylabel='None'>
# Lasso(alpha=1)
# Text(0.5, 1.0, 'alpha:1')
# (-3.0, 6.0)
# <Axes: title={'center': 'alpha:1'}, ylabel='None'>
# Lasso(alpha=3)
# Text(0.5, 1.0, 'alpha:3')
# (-3.0, 6.0)
# <Axes: title={'center': 'alpha:3'}, ylabel='None'>

# %%
coeff_df2.sort_values(by="alpha:0.07", ascending=False)
# Out:
#          alpha:0.07  alpha:0.1  alpha:0.5   alpha:1   alpha:3
# RM         3.789725   3.703202   2.498212  0.949811  0.000000
# CHAS       1.434343   0.955190   0.000000  0.000000  0.000000
# RAD        0.270936   0.274707   0.277451  0.264206  0.061864
# ZN         0.049059   0.049211   0.049544  0.049165  0.037231
# B          0.010248   0.010249   0.009469  0.008247  0.006510
# NOX       -0.000000  -0.000000  -0.000000 -0.000000  0.000000
# AGE       -0.011706  -0.010037   0.003604  0.020910  0.042495
# TAX       -0.014290  -0.014570  -0.015442 -0.015212 -0.008602
# INDUS     -0.042120  -0.036619  -0.005253 -0.000000 -0.000000
# CRIM      -0.098193  -0.097894  -0.083289 -0.063437 -0.000000
# LSTAT     -0.560431  -0.568769  -0.656290 -0.761115 -0.807679
# PTRATIO   -0.765107  -0.770654  -0.758752 -0.722966 -0.265072
# DIS       -1.176583  -1.160538  -0.936605 -0.668790 -0.000000

# %%
plt.plot(alphas, coeff_df2.loc["RM",:])
plt.plot(alphas, coeff_df2.loc["DIS",:])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# 가장 좋은 결과가 나온 0.07을 기준으로 다시 학습

lasso =  Lasso(alpha=0.07)
lasso.fit(X_train, y_train)
y_pred= lasso.predict(X_test)

# 평가지표 출력
print(f'MSE : {mse:.3f}, RMSE : {rmse:.3f}')
print(f'R제곱 : {r2_score(y_test, y_pred):.3f}')


# 릿지
# 최적의 alpha 값으로 다시 모델링한 결과 
# MSE : 19.362, RMSE : 4.400
# R제곱 : 0.728

# 라쏘
# 최적의 alpha 값으로 다시 모델링한 결과 
# MSE : 17.742, RMSE : 4.212
# R제곱 : 0.751

# 최적의 alpha 값으로 다시 모델 생성/학습/예측한 결과
# 릿지와 라쏘 모델이 거의 비슷하지만
# 라쏘가 근소차로 수치가 좋게 보임
# Out:
# Lasso(alpha=0.07)
# MSE : 33.030, RMSE : 5.747
# R제곱 : 0.751

# %% [markdown]
# ## (3)  엘라스틱 넷(Elastic Net) 회귀
#
# - 급격한 회귀 계수 변동을 완화하기 위해 L2 규제를 라쏘 회귀에 추가한 것
# - 단점 : L1과 L2를 결합한 규제로 수행 시간이 상대적으로 오래 걸린다는 것
# - 사이킷런의 ElasticNet 클래스 사용
# - 주요 파라미터 : alpha와 l1_ratio
# - ElasticNet 클래스의 alpha는 Ridge와 Lasso 클래스의 alpha 값과 다름
#
# 엘라스틱 규제 : aL1 + bL2
# - a : L1 규제의 alpha 값
# - b : L2 규제의 alpha 값
# - ElasticNet 클래스의 alpha : a + b
# - ---
# - l1_ratio : a / (a + b)
# - l1_ratio가 0이면 a가 0이 되어 L2 규제와 동일
# - l1_ratio가 1이면 b가 0이 되어 L1규제와 동일

# %%
# ElasticNet 모델 생성/학습/예측
from sklearn.linear_model import ElasticNet

elastic = ElasticNet(alpha=10)
elastic.fit(X_train, y_train)
y_pred=elastic.predict(X_test)
# Out:
# ElasticNet(alpha=10)

# %%
#  평가 
from sklearn.metrics import mean_squared_error, r2_score, root_mean_squared_error

# rmse 구하기
rmse = root_mean_squared_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

# R제곱 : r2_score() 사용
r2 = r2_score(y_test, y_pred)

# 평가 지표 출력
print(f"MSE : {mse:.4F}, RMSE : {rmse:.4f}")
print(f"R제곱 : {r2:.4f}")


# 단순 선형 회귀 모델 결과  : LinearRegression
# MSE : 17.2969, RMSE : 4.1590
# R제곱 : 0.7572

# 릿지 모델 결과
# MSE : 17.6987, RMSE : 4.2070
# R제곱 : 0.7516

# 라쏘 모델 결과
# MSE : 33.0302, RMSE : 5.7472
# R제곱 : 0.5364

# 엘라스틱넷
# MSE : 32.6043, RMSE : 5.7100
# R제곱 : 0.5424

# 엘라스틱넷 모델 성능이 라쏘보다는 미미하게 나은 듯 하지만 별 차이 없음 
# 릿지 모델보다는 R제곱이 현저히 낮게 나옴
# Out:
# MSE : 32.6043, RMSE : 5.7100
# R제곱 : 0.5424

# %%
# 교차 검증 수행

from sklearn.model_selection import cross_val_score

# 5개 Fold 셋으로 MSE 구함 
neg_mse_scores = cross_val_score(elastic,
                                 X_data, y_target,
                                 scoring='neg_mean_squared_error',
                                 cv=5)


rmse_scores = np.sqrt(-1 * neg_mse_scores)
avg_rmse = np.mean(rmse_scores)

# 평가 지표 출력
print('5 Folds 교차검증 개별 Negative MSE scores : ', np.round(neg_mse_scores, 2))
print('5 Folds 교차검증 개별 RMSE scores : ', np.round(rmse_scores, 2))
print('5 Folds 교차검증 평균 RMSE : ', np.round(avg_rmse, 3))
# Out:
# 5 Folds 교차검증 개별 Negative MSE scores :  [-26.39 -43.13 -77.93 -60.01 -16.65]
# 5 Folds 교차검증 개별 RMSE scores :  [5.14 6.57 8.83 7.75 4.08]
# 5 Folds 교차검증 평균 RMSE :  6.472

# %%
# alpha 값을 [0.07, 0.1, 0.5, 1, 3] 으로 변경하면서 
# RMSE와 회귀 계수 값의 변화 측정
alphas = [0.07, 0.1, 0.5, 1, 3]

# alpha 값에 따른 평균 RMSE 구하기 
for alpha in alphas:
    elastic = ElasticNet(alpha=alpha)

    # 5개 Fold 셋으로 MSE 구함 
    neg_mse_scores = cross_val_score(elastic,
                                     X_data, y_target,
                                     scoring='neg_mean_squared_error',
                                     cv=5)    
    
    rmse_scores = np.sqrt(-1 * neg_mse_scores)
    avg_rmse = np.mean(rmse_scores)
    print(f'alpha {alpha} 일 때 5 Folds 교차검증 평균 RMSE : {avg_rmse:.4f}')
    # alpha가 0.5일때 가장 좋은 성능을 보임
# Out:
# alpha 0.07 일 때 5 Folds 교차검증 평균 RMSE : 5.5032
# alpha 0.1 일 때 5 Folds 교차검증 평균 RMSE : 5.4784
# alpha 0.5 일 때 5 Folds 교차검증 평균 RMSE : 5.4127
# alpha 1 일 때 5 Folds 교차검증 평균 RMSE : 5.5216
# alpha 3 일 때 5 Folds 교차검증 평균 RMSE : 5.9536

# %%
# 각 alpha에 따른 회귀 계수 값을 시각화
fig, axs = plt.subplots(figsize=(18, 6), nrows=1, ncols=5)

# 각 alpha 값을 df로 저장
coeff_df2 = pd.DataFrame()

for pos, alpha in enumerate(alphas):
    elastic = ElasticNet(alpha=alpha) # 초기화
    elastic.fit(X_data, y_target) # 학습
    
    # df에 추가
    coeff = pd.Series(data=elastic.coef_, index=X_data.columns)
    colname = 'alpha:' + str(alpha)
    coeff_df2[colname] = coeff
    
    # 막대 그래프로 회귀 계수 시각화 : 정렬 후 출력
    coeff = coeff.sort_values(ascending=False)
    axs[pos].set_title(colname)
    axs[pos].set_xlim(-3, 6)
    sns.barplot(x=coeff.values, y=coeff.index, ax=axs[pos])
    
plt.show()
# Out:
# ElasticNet(alpha=0.07)
# Text(0.5, 1.0, 'alpha:0.07')
# (-3.0, 6.0)
# <Axes: title={'center': 'alpha:0.07'}, ylabel='None'>
# ElasticNet(alpha=0.1)
# Text(0.5, 1.0, 'alpha:0.1')
# (-3.0, 6.0)
# <Axes: title={'center': 'alpha:0.1'}, ylabel='None'>
# ElasticNet(alpha=0.5)
# Text(0.5, 1.0, 'alpha:0.5')
# (-3.0, 6.0)
# <Axes: title={'center': 'alpha:0.5'}, ylabel='None'>
# ElasticNet(alpha=1)
# Text(0.5, 1.0, 'alpha:1')
# (-3.0, 6.0)
# <Axes: title={'center': 'alpha:1'}, ylabel='None'>
# ElasticNet(alpha=3)
# Text(0.5, 1.0, 'alpha:3')
# (-3.0, 6.0)
# <Axes: title={'center': 'alpha:3'}, ylabel='None'>

# %%
# alpha 값에 따른 칼럼별 회귀 계수 출력
coeff_df2.sort_values(by='alpha:0.07', ascending=False)
# Out:
#          alpha:0.07  alpha:0.1  alpha:0.5   alpha:1   alpha:3
# RM         3.445833   3.252662   1.723610  0.933936  0.000000
# CHAS       1.287475   0.987970   0.000000  0.000000  0.000000
# RAD        0.284007   0.288726   0.311583  0.301569  0.199147
# ZN         0.050678   0.051377   0.054045  0.053240  0.046018
# B          0.010035   0.009963   0.008997  0.008339  0.007271
# AGE       -0.008997  -0.007219   0.009475  0.020579  0.038926
# TAX       -0.014636  -0.014952  -0.016300 -0.016439 -0.013587
# INDUS     -0.045733  -0.045901  -0.031702 -0.012657 -0.000000
# CRIM      -0.100331  -0.100079  -0.092503 -0.080371 -0.040903
# NOX       -0.484864  -0.059533  -0.000000 -0.000000 -0.000000
# LSTAT     -0.582983  -0.598184  -0.706176 -0.758426 -0.794154
# PTRATIO   -0.790069  -0.793502  -0.803835 -0.748046 -0.476192
# DIS       -1.199548  -1.181402  -0.989655 -0.762044 -0.224409

# %%
# 가장 좋은 결과가 나온 0.5을 기준으로 다시 학습
elastic = ElasticNet(alpha=0.5)
elastic.fit(X_train, y_train)
y_pred = elastic.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

# 평가지표 출력
print(f'MSE : {mse:.3f}, RMSE : {rmse:.3f}')
print(f'R제곱 : {r2_score(y_test, y_pred):.3f}')

# 단순 선형 회귀 모델 결과
# MSE : 17.2969, RMSE : 4.1590
# R제곱 : 0.7572

# 릿지
# 최적의 alpha 값으로 다시 모델링한 결과 
# MSE : 19.362, RMSE : 4.400
# R제곱 : 0.728

# 라쏘
# 최적의 alpha 값으로 다시 모델링한 결과 
# MSE : 33.030, RMSE : 5.747
# R제곱 : 0.751

# 엘라스틱 넷
# MSE : 19.978, RMSE : 4.470
# R제곱 : 0.720
# Out:
# ElasticNet(alpha=0.5)
# MSE : 19.978, RMSE : 4.470
# R제곱 : 0.720

# %% [markdown]
# - 컬럼 분포 변경 후 엘라스틱넥 모델링 연습문제

# %% [markdown]
# ### 릿지, 라쏘, 엘라스틱넷 회귀 결론

# %% [markdown]
# - 기본 데이터 형태에 릿지, 라쏘, 엘라스틱넷 적용 했을때의 차이가 크게 없음
# - 데이터 형태 변경(scaling, log, outlier) 등 진행해서 형태 바꾼 뒤에 해보면 어떨지는 자체 실습

# %% [markdown]
# - 규제 선형 회귀의 가장 대표적인 기법인 릿지, 라쏘, 엘라스틱넷 회귀 결론
#     - 어떤 알고리즘이 좋은지는 알고리즘에 따라 다름
#     - **하이퍼파라미터 튜닝**, **피처 엔지니어링** 통해서 최적 예측 성능을 찾아내야함
#     - 선형 회귀인 경우, 최적 하이퍼파라미터 찾아내는 과정 못지않게 **분포를 정규화**시키는 작업이 중요
